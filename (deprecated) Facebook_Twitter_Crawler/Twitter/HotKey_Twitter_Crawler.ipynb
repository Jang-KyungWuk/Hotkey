# %%
from requests import get, post, Session
from urllib import parse
from datetime import datetime

# %%
def get_guest_token(session): #guest token값을 return
    headers = {
     'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA'
    }
    resp = session.post('https://api.twitter.com/1.1/guest/activate.json', headers = headers)
    print('guest_token 설정 완료.....')
    return session, resp.json()['guest_token']

# %%
session, guest_token = get_guest_token(Session())
# Out:
# guest_token 설정 완료.....

# %%
se

# %%
def set_params(keyword, session): #header와 parameter값을 설정해준다.
    params = {'include_profile_interstitial_type': '1',
 'include_blocking': '1',
 'include_blocked_by': '1',
 'include_followed_by': '1',
 'include_want_retweets': '1',
 'include_mute_edge': '1',
 'include_can_dm': '1',
 'include_can_media_tag': '1',
 'include_ext_has_nft_avatar': '1',
 'skip_status': '1',
 'cards_platform': 'Web-12',
 'include_cards': '1',
 'include_ext_alt_text': 'true',
 'include_ext_limited_action_results': 'false',
 'include_quote_count': 'true',
 'include_reply_count': '1',
 'tweet_mode': 'extended',
 'include_ext_collab_control': 'true',
 'include_entities': 'true',
 'include_user_entities': 'true',
 'include_ext_media_color': 'true',
 'include_ext_media_availability': 'true',
 'include_ext_sensitive_media_warning': 'true',
 'include_ext_trusted_friends_metadata': 'true',
 'send_error_codes': 'true',
 'simple_quoted_tweet': 'true',
 'q': '',
 'tweet_search_mode': 'live',
 'count': '20',
 'query_source': 'recent_search_click',
 'pc': '1',
 'spelling_corrections': '1',
 'include_ext_edit_control': 'true',
 'ext': 'mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe'}
    
    headers = {'authority': 'twitter.com',
 'method': 'GET',
 #'path': '/i/api/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=%23%EB%83%89%EB%8F%99%EB%A7%8C%EB%91%90&tweet_search_mode=live&count=20&query_source=recent_search_click&pc=1&spelling_corrections=1&include_ext_edit_control=true&ext=mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe',
 'scheme': 'https',
 'accept': '*/*',
 'accept-encoding': '',
 'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
 'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
 #'cookie': 'guest_id_marketing=v1%3A166667526885979112; guest_id_ads=v1%3A166667526885979112; _ga=GA1.2.90083710.1666675272; _gid=GA1.2.208720928.1666675272; kdt=haoAurXsKba1QzgQArmyjksDpPIxI2NgYdsKXgdi; dnt=1; _sl=1; personalization_id="v1_s+fyK3WK3jNZxdSZKpb+4g=="; guest_id=v1%3A166676189695496518; ct0=c957e33ed33737a2fbe46ccce2767ad1; gt=1585140401979412480; g_state={"i_l":1,"i_p":1666769101996}',
 'referer': 'https://twitter.com/search?q={}&src=recent_search_click&f=live'.format(parse.quote('#'+keyword)), # 해쉬태그로 검색할경우
 'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
 'sec-ch-ua-mobile': '?0',
 'sec-ch-ua-platform': '"Windows"',
 'sec-fetch-dest': 'empty',
 'sec-fetch-mode': 'cors',
 'sec-fetch-site': 'same-origin',
 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36',
 #csrf가 없어도되는지?
 #'x-csrf-token': 'c957e33ed33737a2fbe46ccce2767ad1',
 'x-guest-token': '',
 'x-twitter-active-user': 'yes',
 'x-twitter-client-language': 'ko'}

    params['q'] = parse.quote('#'+keyword)
    #headers의 accept-encoding을 json으로 교체
    headers['accept-encoding'] = 'json'
    
    #headers의 x-guest-token 채우기
    #guest-token받아오기
    session, headers['x-guest-token'] = get_guest_token(session)
    
    #headers, parameters 설정 끝
    print('헤더 및 파라미터 설정 완료.....')
    return (params, headers, session)

# %%
session = Session()

# %%
resp = session.get('https://twitter.com/i/api/graphql/ojKlWLVp7ttCKanb7rii6Q/UserMedia?variables=%7B%22userId%22%3A%221471950141632356357%22%2C%22count%22%3A20%2C%22includePromotedContent%22%3Afalse%2C%22withSuperFollowsUserFields%22%3Atrue%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%2C%22withSuperFollowsTweetFields%22%3Atrue%2C%22withClientEventToken%22%3Afalse%2C%22withBirdwatchNotes%22%3Afalse%2C%22withVoice%22%3Atrue%2C%22withV2Timeline%22%3Atrue%7D&features=%7B%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22view_counts_public_visibility_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22responsive_web_uc_gql_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Atrue%7D')

# %%
resp
# Out:
# <Response [403]>

# %%
session.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='guest_id', value='v1%3A167060811895024546', port=None, port_specified=False, domain='.twitter.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1733680119, discard=False, comment=None, comment_url=None, rest={'SameSite': 'None'}, rfc2109=False), Cookie(version=0, name='guest_id_ads', value='v1%3A167060811895024546', port=None, port_specified=False, domain='.twitter.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1733680119, discard=False, comment=None, comment_url=None, rest={'SameSite': 'None'}, rfc2109=False), Cookie(version=0, name='guest_id_marketing', value='v1%3A167060811895024546', port=None, port_specified=False, domain='.twitter.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1733680119, discard=False, comment=None, comment_url=None, rest={'SameSite': 'None'}, rfc2109=False), Cookie(version=0, name='personalization_id', value='"v1_lpOLQ/E+6m+QqOora/8vqQ=="', port=None, port_specified=False, domain='.twitter.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1733680119, discard=False, comment=None, comment_url=None, rest={'SameSite': 'None'}, rfc2109=False)]>

# %%
url = ''

data.user.result.timeline_v2.timeline.instructions[0].entries[0].content.itemContent.tweet_results.result.legacy.entities.media[0].media_url_https

# %%
def hot_key_twitter(nposts): #keyword는 검색할 변수, nposts는 크롤링하고자하는 게시물 수
    keyword = input('분석할 해시태그를 입력하세요 : ')
    while (len(keyword)==0):
        keyword = input('한 글자 이상의 해시태그를 입력해주세요 :')
    print('수집 시작... 수집할 게시물 수 :', nposts)
    
    totalbf = datetime.now()
    nopostcnt = 0
    #반환할 textlist
    textlist = list()
    ncrawled = 0
    #session 생성
    session = Session()
    #parameter 초기값 받아오기
    before = datetime.now()
    params, headers, session = set_params(keyword, session)
    print('사전설정 소요시간 :', datetime.now() - before)
    
    #session 인스턴스 생성
    
    request_url = 'https://twitter.com/i/api/2/search/adaptive.json'
    
    #get 요청을 보낼 url 완성
    keys = list(params.keys())
    values = list(params.values())
    get_request_url = request_url+'?'
    for cursor in range(len(keys)):
        get_request_url+='%s=%s&'%(keys[cursor],values[cursor]) 
    get_request_url = get_request_url[:-1]
    
    #headers의 'path' 변수 변경
    headers['path'] = get_request_url[19:]
    
    before = datetime.now()
    #1페이지 검색
    print('---------------------------------------수집중 : {}페이지...-----------------------------------------'.format(1))
    #get 요청 보내기 (1페이지)
    try:
        resp = session.get(get_request_url,headers=headers)
        respjson = resp.json()
        ncontents = len(respjson['globalObjects']['tweets'].keys())
    
        if ncontents == 0 :
            nopostcnt += 1
        
        tmpcrawled = ncrawled
        textlist.append(list())
        print('게시물 개수 :', ncontents)
        for i in respjson['globalObjects']['tweets'].keys():
            textlist[0].append(respjson['globalObjects']['tweets'][i]['full_text'])
            ncrawled+=1
            if ncrawled >= nposts:
                print('수집 완료! 수집한 총 게시물 수 :', ncrawled)
                print('총 소요시간 :', datetime.now()-totalbf)
                return textlist
        print('수집된 개시물 개수 :', ncrawled)
        print('소요시간 :', datetime.now()-before)
        #다음 페이지 가르키는 커서 변수에 값 넣어주기
        next_pg = respjson['timeline']['instructions'][0]['addEntries']['entries'][-1]['content']['operation']['cursor']['value']
    except:
        print('\n\n\n!!!!!!!!!!!!!!!******알 수 없는 에러입니다******!!!!!!!!!!!!!!!\n\n\n')
        print('수집한 총 게시물 수 :', ncrawled)
        print('총 소요시간 :', datetime.now()-totalbf)
        return textlist
    
    #2페이지부터 추가 검색
    cur_page = 2
    while True:
        try :
            tmpcrawled = ncrawled
            params['cursor'] = next_pg
            get_request_url = request_url+'?'
            keys = list(params.keys())
            values = list(params.values())
            for cursor in range(len(keys)):
                get_request_url+='%s=%s&'%(keys[cursor],values[cursor]) 
            get_request_url = get_request_url[:-1]
        
            print('---------------------------------------수집중 : {}페이지...-----------------------------------------'.format(cur_page))
            before = datetime.now()
            resp = session.get(get_request_url,headers=headers)
            respjson = resp.json()
            ncontents = len(respjson['globalObjects']['tweets'].keys())
            if ncontents == 0 : #5페이지 연속으로 빈페이지가 나오는경우
                if nopostcnt > 5:
                    print('더 이상 수집할 게시물이 없습니다.')
                    print('수집한 총 게시물 수 :', ncrawled)
                    print('총 소요시간 :', datetime.now()-totalbf)
                    return textlist
                nopostcnt += 1
            else:
                nopostcnt = 0
        
            next_pg = respjson['timeline']['instructions'][-1]['replaceEntry']['entry']['content']['operation']['cursor']['value']
        
            textlist.append(list())
            print('게시물 개수:', ncontents)
            for i in respjson['globalObjects']['tweets'].keys():
                textlist[-1].append(respjson['globalObjects']['tweets'][i]['full_text'])
                ncrawled+=1
                if ncrawled >= nposts:
                    print('수집 완료! 수집한 총 게시물 수 :', ncrawled)
                    print('총 소요시간 :', datetime.now()-totalbf)
                    return textlist
            print('수집된 개시물 개수 :', ncrawled)
            print('소요시간 :', datetime.now()-before)
            cur_page+=1
        except:
            print('\n\n\n!!!!!!!!!!!!!!!******알 수 없는 에러입니다******!!!!!!!!!!!!!!!\n\n\n')
            print('수집한 총 게시물 수 :', ncrawled)
            print('총 소요시간 :', datetime.now()-totalbf)
            return textlist
    
    print('수집 완료! 수집한 총 게시물 수 :', ncrawled)
    print('총 소요시간 :', datetime.now()-totalbf)
    return textlist

# %% [markdown]
# # 여기서 실행

# %%
maxposts = 1000
textlist = hot_key_twitter(maxposts)
# Out:
# 분석할 해시태그를 입력하세요 : 강인경
# 수집 시작... 수집할 게시물 수 : 1000
# guest_token 설정 완료.....
# 헤더 및 파라미터 설정 완료.....
# 사전설정 소요시간 : 0:00:00.249319
# ---------------------------------------수집중 : 1페이지...-----------------------------------------
# 게시물 개수 : 19
# 수집된 개시물 개수 : 19
# 소요시간 : 0:00:00.984735
# ---------------------------------------수집중 : 2페이지...-----------------------------------------
# 게시물 개수: 20
# 수집된 개시물 개수 : 39
# 소요시간 : 0:00:00.877781
# ---------------------------------------수집중 : 3페이지...-----------------------------------------
# 게시물 개수: 14
# 수집된 개시물 개수 : 53
# 소요시간 : 0:00:00.888816
# ---------------------------------------수집중 : 4페이지...-----------------------------------------
# 게시물 개수: 2
# 수집된 개시물 개수 : 55
# 소요시간 : 0:00:00.394422
# ---------------------------------------수집중 : 5페이지...-----------------------------------------
# 게시물 개수: 7
# 수집된 개시물 개수 : 62
# 소요시간 : 0:00:00.606716
# ---------------------------------------수집중 : 6페이지...-----------------------------------------
# 게시물 개수: 2
# 수집된 개시물 개수 : 64
# 소요시간 : 0:00:00.485875
# ---------------------------------------수집중 : 7페이지...-----------------------------------------
# 게시물 개수: 2
# 수집된 개시물 개수 : 66
# 소요시간 : 0:00:00.488893
# ---------------------------------------수집중 : 8페이지...-----------------------------------------
# 게시물 개수: 1
# 수집된 개시물 개수 : 67
# 소요시간 : 0:00:00.372291
# ---------------------------------------수집중 : 9페이지...-----------------------------------------
# 게시물 개수: 6
# 수집된 개시물 개수 : 73
# 소요시간 : 0:00:00.568860
# ---------------------------------------수집중 : 10페이지...-----------------------------------------
# 게시물 개수: 14
# 수집된 개시물 개수 : 87
# 소요시간 : 0:00:00.864078
# ---------------------------------------수집중 : 11페이지...-----------------------------------------
# 게시물 개수: 3
# 수집된 개시물 개수 : 90
# 소요시간 : 0:00:00.514874
# ---------------------------------------수집중 : 12페이지...-----------------------------------------
# 게시물 개수: 1
# 수집된 개시물 개수 : 91
# 소요시간 : 0:00:00.355971
# ---------------------------------------수집중 : 13페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 91
# 소요시간 : 0:00:00.327602
# ---------------------------------------수집중 : 14페이지...-----------------------------------------
# 게시물 개수: 3
# 수집된 개시물 개수 : 94
# 소요시간 : 0:00:00.499415
# ---------------------------------------수집중 : 15페이지...-----------------------------------------
# 게시물 개수: 1
# 수집된 개시물 개수 : 95
# 소요시간 : 0:00:00.322403
# ---------------------------------------수집중 : 16페이지...-----------------------------------------
# 게시물 개수: 2
# 수집된 개시물 개수 : 97
# 소요시간 : 0:00:00.284497
# ---------------------------------------수집중 : 17페이지...-----------------------------------------
# 게시물 개수: 1
# 수집된 개시물 개수 : 98
# 소요시간 : 0:00:00.414577
# ---------------------------------------수집중 : 18페이지...-----------------------------------------
# 게시물 개수: 8
# 수집된 개시물 개수 : 106
# 소요시간 : 0:00:00.646336
# ---------------------------------------수집중 : 19페이지...-----------------------------------------
# 게시물 개수: 16
# 수집된 개시물 개수 : 122
# 소요시간 : 0:00:01.051065
# ---------------------------------------수집중 : 20페이지...-----------------------------------------
# 게시물 개수: 20
# 수집된 개시물 개수 : 142
# 소요시간 : 0:00:00.996056
# ---------------------------------------수집중 : 21페이지...-----------------------------------------
# 게시물 개수: 20
# 수집된 개시물 개수 : 162
# 소요시간 : 0:00:00.720521
# ---------------------------------------수집중 : 22페이지...-----------------------------------------
# 게시물 개수: 18
# 수집된 개시물 개수 : 180
# 소요시간 : 0:00:00.872044
# ---------------------------------------수집중 : 23페이지...-----------------------------------------
# 게시물 개수: 13
# 수집된 개시물 개수 : 193
# 소요시간 : 0:00:00.897697
# ---------------------------------------수집중 : 24페이지...-----------------------------------------
# 게시물 개수: 5
# 수집된 개시물 개수 : 198
# 소요시간 : 0:00:00.493819
# ---------------------------------------수집중 : 25페이지...-----------------------------------------
# 게시물 개수: 16
# 수집된 개시물 개수 : 214
# 소요시간 : 0:00:00.820998
# ---------------------------------------수집중 : 26페이지...-----------------------------------------
# 게시물 개수: 19
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.779795
# ---------------------------------------수집중 : 27페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.181868
# ---------------------------------------수집중 : 28페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.196557
# ---------------------------------------수집중 : 29페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.178206
# ---------------------------------------수집중 : 30페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.187034
# ---------------------------------------수집중 : 31페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.189732
# ---------------------------------------수집중 : 32페이지...-----------------------------------------
# 게시물 개수: 0
# 수집된 개시물 개수 : 233
# 소요시간 : 0:00:00.176719
# ---------------------------------------수집중 : 33페이지...-----------------------------------------
# 더 이상 수집할 게시물이 없습니다.
# 수집한 총 게시물 수 : 233
# 총 소요시간 : 0:00:18.065962

# %%
textlist
# Out:
# [['강인경 노출, 이게 맞냐? 19금 후방주의\n#후방주의 #강인경 #글래머 #몸매 #노출 \nhttps://t.co/sRWH55fp2D\nhttps://t.co/sRWH55fp2D\nhttps://t.co/sRWH55fp2D',
#   '강인경 역대급 노출, 수위가 장난 아니네 19금, 후방주의 \n#후방주의 #글래머 #노출 #누드 #세미누드 #19금 #가슴 #꼭지 #강인경 \nhttps://t.co/g3ixYXAMoW\nhttps://t.co/g3ixYXAMoW\nhttps://t.co/g3ixYXAMoW',
#   '강인경 남친이 그저 존나 부러운 이유 ㅎㄷㄷ 후방주의\n#강인경 #글래머 #몸매 #후방주의 \nhttps://t.co/7426hPxqW9\nhttps://t.co/7426hPxqW9\nhttps://t.co/7426hPxqW9',
#   '줄에 묶여 있는 강인경 ㅎㄷㄷ 후방주의\n#강인경 #후방주의 #글래머 #몸매 #골반 \nhttps://t.co/UstPra3DRH\nhttps://t.co/UstPra3DRH\nhttps://t.co/UstPra3DRH',
#   '강인경 몸매 자랑 M자 까지 ㅎㄷㄷ 후방주의\n#후방주의 #강인경 #몸매 #글래머 #M자 #ㅎㄷㄷ \nhttps://t.co/6BrRpO7P3t\nhttps://t.co/6BrRpO7P3t\nhttps://t.co/6BrRpO7P3t\nhttps://t.co/6BrRpO7P3t',
#   '빠꾸 없는 강인경 인스타 사진 ㅎㄷㄷ 후방주의\n#후방주의 #강인경 #글래머 #몸매 #미모 #슴가 \nhttps://t.co/N96OIlkUIm\nhttps://t.co/N96OIlkUIm\nhttps://t.co/N96OIlkUIm',
#   '극후방 강인경 신작, ㅎㄷㄷ 후방주의 하세요, 노출\n#강인경 #글래머 #몸매 #노출 #골반 #누드 \nhttps://t.co/ZOK8UIhDzE\nhttps://t.co/ZOK8UIhDzE\nhttps://t.co/ZOK8UIhDzE',
#   '강인경 꼭지만 딱 가린 비키니 ㅗㅜㅑ 후방주의\n#강인경 #글래머 #후방주의 #비키니 #가슴 #몸매 #오우야 \nhttps://t.co/i5pMRu5nc3\nhttps://t.co/i5pMRu5nc3\nhttps://t.co/i5pMRu5nc3',
#   '강인경 인스타 사진 후방주의 ㅎㄷㄷ\n#강인경 #인스타 #후방주의 #글래머 #몸매 \nhttps://t.co/VhwwROwHZj\nhttps://t.co/VhwwROwHZj\nhttps://t.co/VhwwROwHZj\nhttps://t.co/VhwwROwHZj',
#   '강인경 해변 비키니 오우야 후방주의\n#강인경 #비키니 #글래머 #몸매 #후방주의 \nhttps://t.co/1cH86YY6Uy\nhttps://t.co/1cH86YY6Uy\nhttps://t.co/1cH86YY6Uy',
#   '옷을 입지 않은 강인경 ㅎㄷㄷ 후방주의 19금!!!!\n#후방주의 #누드 #나체 #강인경 #글래머 #몸매 #골반',
#   '강인경 몸스타그램 신작 ㅗㅜㅑ 후방주의\n#강인경 #후방주의 #글래머 #노출 #누드 #몸매 #골반 \nhttps://t.co/G9xwQaJaxl\nhttps://t.co/G9xwQaJaxl\nhttps://t.co/G9xwQaJaxl',
#   '강인경 움짤 모음 ㅎㄷㄷ 후방주의\n#강인경 #몸매 #글래머 #후방주의 \nhttps://t.co/Wn9RgTY8fe\nhttps://t.co/Wn9RgTY8fe\nhttps://t.co/Wn9RgTY8fe',
#   "후드티를 '성인용'으로 만들어버리는 패기 https://t.co/OcBcNyPBVk #강인경 #인스타그램 #셀럽",
#   '메이드복 입은 강인경 후방주의 ㅎㄷㄷ\n#후방주의 #강인경 #몸매 #글래머 #골반 \nhttps://t.co/qwXDyL95Rf\nhttps://t.co/qwXDyL95Rf\nhttps://t.co/qwXDyL95Rf',
#   '하이레그 입은 메이드 강인경 ㅎㄷㄷ 후방주의\n#후방주의 #하이레그 #메이드 #강인경 #글래머 #몸매 \nhttps://t.co/nCtQCcJn3n\nhttps://t.co/nCtQCcJn3n\nhttps://t.co/nCtQCcJn3n',
#   '입어서 사람들을 놀라게 한 여자 https://t.co/CCTyZ8P29R #강인경 #인스타 #셀럽',
#   '강인경 꼭지 가리개 ㅎㄷㄷ 후방주의\n#강인경 #글래머 #몸매 #후방주의 \nhttps://t.co/27k8MmQ4Rw\nhttps://t.co/27k8MmQ4Rw\nhttps://t.co/27k8MmQ4Rw',
#   '다짜고짜 셔츠 올리는 강인경 ㅎㄷㄷ 후방주의\n#강인경 #후방주의 #몸매 #글래머 #노출 \nhttps://t.co/Wz08WcG1NJ\nhttps://t.co/Wz08WcG1NJ\nhttps://t.co/Wz08WcG1NJ'],
#  ['강인경 아슬아슬 하게 가린 수영복 \n#강인경 #수영복 #노출 #몸매 #글래머 #후방주의 \nhttps://t.co/51zUvtf8A8\nhttps://t.co/51zUvtf8A8\nhttps://t.co/51zUvtf8A8',
#   '강인경 움짤 모음 ㅗㅜㅑ\n#강인경 #움짤 #노출 #몸매 #글래머 \nhttps://t.co/cwIFdEVUYr\nhttps://t.co/cwIFdEVUYr\nhttps://t.co/cwIFdEVUYr https://t.co/WJFaGsFwRZ',
#   '강인경 언더붑, 비키니 인스타\n#강인경 #비키니 #인스타 #언더붑 \nhttps://t.co/K647DUYNHf\nhttps://t.co/K647DUYNHf\nhttps://t.co/K647DUYNHf https://t.co/PlOlLt2xHQ',
#   '극 후방주의 강인경, 오우야 이거 올려도 되나\n#강인경 #후방주의 #오우야 \nhttps://t.co/rVWw1JjbBN\nhttps://t.co/rVWw1JjbBN\nhttps://t.co/rVWw1JjbBN\nhttps://t.co/rVWw1JjbBN',
#   '코스프레에 진심인 강인경 후방주의\n#후방주의 #강인경 #몸매 #글래머 #오우야 #코스프레 \nhttps://t.co/yCQFXogJnE\nhttps://t.co/yCQFXogJnE\nhttps://t.co/yCQFXogJnE',
#   '줄에 묶여 구속당한 강인경\n#강인경 #구속 #글래머 #엉덩이 #오우야 \nhttps://t.co/9xFOZG4Gyy\nhttps://t.co/9xFOZG4Gyy\nhttps://t.co/9xFOZG4Gyy https://t.co/WnZHfpjukT',
#   '수험생들의 기운이 불타오르네 ㄷㄷ https://t.co/3HYN5psgU8 #강인경 #수능 #노출',
#   '강인경 해변 바다 수영복 ㅎㄷㄷ 후방주의\n#강인경 #몸매 #글래머 #후방주의 #골반 \nhttps://t.co/RSkMqxTlva\nhttps://t.co/RSkMqxTlva\nhttps://t.co/RSkMqxTlva',
#   '강인경 다음 컨셉이 무섭다는데 난 왜 지금이 더 무섭냐\n#강인경 #19금 #후방주의 #가슴 \nhttps://t.co/YA6MRJEWxV\nhttps://t.co/YA6MRJEWxV\nhttps://t.co/YA6MRJEWxV',
#   '수능 응원하는 강인경\n#강인경 #섹시 #노출 #가슴 \nhttps://t.co/DBeZCZW8rO\nhttps://t.co/DBeZCZW8rO\nhttps://t.co/DBeZCZW8rO',
#   '강인경 19금 화보 수위 ㅎㄷㄷ\n#강인경 #19금 #화보 #몸매 \nhttps://t.co/HQzT5YoSjo\nhttps://t.co/HQzT5YoSjo\nhttps://t.co/HQzT5YoSjo',
#   '야심한 밤에 외출하는 강인경\n#강인경 #몸매 #글래머 #노출 #골반 #후방주의 \nhttps://t.co/2jRTixBMFx\nhttps://t.co/2jRTixBMFx\nhttps://t.co/2jRTixBMFx',
#   '노란 끈 팬티 강인경 화보들  오우야\n#끈팬티 #강인경 #오우야 #몸매 #글래머 #19금 \nhttps://t.co/xPV5Sbc1od\nhttps://t.co/xPV5Sbc1od\nhttps://t.co/xPV5Sbc1od',
#   '강인경 꼭지만 가린 노브라 누드\n#강인경 #노브라 #누드 #꼭지 #글래머 \nhttps://t.co/XpBxAf31s2\nhttps://t.co/XpBxAf31s2\nhttps://t.co/XpBxAf31s2',
#   '강인경 아슬하게 가린 수영복 사진\n#강인경 #수영복 #19금 #몸매 #글래머 #미쳤다 \nhttps://t.co/aZLnhV62pP\nhttps://t.co/aZLnhV62pP\nhttps://t.co/aZLnhV62pP',
#   '강인경 노브라 꼭지 인스타\n#강인경 #노브라 #꼭지 #노출 #글래머 \nhttps://t.co/tGEAFWTgTL\nhttps://t.co/tGEAFWTgTL\nhttps://t.co/tGEAFWTgTL',
#   '강인경 큰거 하나 오나?\n#강인경 #글래머 #몸매 \nhttps://t.co/IbAQhtQ6cE\nhttps://t.co/IbAQhtQ6cE\nhttps://t.co/IbAQhtQ6cE https://t.co/wfc0AWosvj',
#   '강인경 인스타 노브라 묵직한 마음 꼭지 노출\n#강인경 #인스타 #노브라 #노출 #몸매 #글래머 \nhttps://t.co/Mw81SCO9WA\nhttps://t.co/Mw81SCO9WA\nhttps://t.co/Mw81SCO9WA',
#   '강인경 이번 화보 컨셉 골든 샤워 , 후방주의\n#강인경 #글래머 #몸매 #비주얼 #골반 #후방주의 #화보 \nhttps://t.co/iBQzusjZrT\nhttps://t.co/iBQzusjZrT\nhttps://t.co/iBQzusjZrT',
#   '강인경 체크 비키니 사진 모음 ㅗㅜㅑ\n#강인경 #비키니 #글래머 #몸매 \nhttps://t.co/Xxrz1iTm4P\nhttps://t.co/Xxrz1iTm4P\nhttps://t.co/Xxrz1iTm4P https://t.co/PHbdP6Jz0f'],
#  ['강인경 언더붑 비키니 인스타\n#강인경 #언더붑 #강인경인스타 #강인경비키니 \nhttps://t.co/G5DEHEte88',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/dMhewC3WcE\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\n0biiy',
#   '"외모도 점점 좋아지시는 듯" (네티즌 반응) https://t.co/iSuLhwpLMN #강인경 #맥심모델 #비키니',
#   '어디에서 본 포즈인가 했더니... https://t.co/jA2fYYms3X #강인경 #빼빼로데이 #빼빼로데이화보',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/hf6l7RIBr5\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\nlwna8',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/Krb63hbMHs\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\ny14l8',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/vAGWFu6V5H\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\n0znoy',
#   '많이 파진 꽃블라우스 마음골 강인경 누나\n#강인경 \nhttps://t.co/21ZtOxVLi3',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/iLTLUGzPW1\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\ni2wfd',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/SE7jOIHwEp\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\nk7ydj',
#   "몸매 끝판왕...맥심 모델 강인경이 침대 누워 '파격 노출', 정말 화끈합니다\nhttps://t.co/cfMmWjYOB9\n#모델 #강인경 #파격노출 #섹시 #7m스포츠 #7m스코어 https://t.co/J5wrfIE2WS",
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/UJaGGzDQbt\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\nxsc21',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/EF9boqdS7Q\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\nz19gn',
#   '강인경 인스타 마음 노출\n#강인경 #강인경인스타 \nhttps://t.co/OsosayjTeq'],
#  ['15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/tNlHjWeWhP\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\n45kgk',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/gaWfMsomjH\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\nx57yw'],
#  ['15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/xgOIRZBzey\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\n3tk5x',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/qIfDtCpwIH\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\n10a69',
#   '국내 최대의 규모와 안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #김연아 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인 https://t.co/6NFLxBHWis',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/bph3mZ7y8e\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\ng7eec',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/YTiAQN013I\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\ndm6k3',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/IV2iY06Nm5\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\n4mi6t',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/V27Usb12uT\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\njo7z6'],
#  ['국내 최대의 규모와 안전을 자랑하는 라이브온 온라인슬롯 이벤트 진행중입니다!! \n#토토홍보 #슬롯사이트 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인 https://t.co/DosIvuhXFV',
#   '15년차 안전 메이저 알론\n추천코드 풀렸습니다.\n\n주소: https://t.co/Di7R4K94ku\n코드: tw77\n\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁\n#강인경 #슬롯 #온라인슬롯 #이벤트 #bts #롤드컵 #섹트 #성인 여성 #카카오주식\n\nroi8g'],
#  ['F컵 맥심 모델 강인경 팔로워수 아트그라비아 화보 몸매 온리패스 INTP 인스타\n\n#F컵 #맥심 #모델 #강인경 #팔로워수 #아트그라비아 #화보 #거유 #폭유 #가슴골 #슴골 #색기 #골반 #엉덩이 #몸매 #온리패스 #INTP #인스타\n\nhttps://t.co/gaR1Voocyp',
#   '국내 최대의 규모와 안전을 자랑하는 라이브온 온라인슬롯 이벤트 진행중입니다!! \n#토토홍보 #슬롯사이트 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인 https://t.co/997vHwKe7g'],
#  ['국내 최대의 규모와 안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인 https://t.co/HbWDBmYsGg'],
#  ['#토토홍보 #토토광고 #온라인카지노 #파워볼 #손흥민득점 #핫이슈 #강인경 #카카오먹통 #아이폰14 #스포츠게임 https://t.co/Hz1ERuFxNr',
#   '순한맛도 나름 매운 인경갓 인스타 사진\n\nhttps://t.co/fROV1gaJnd\n\n#인경 #강인경 #노출 #글래머 #노출 #ㅎㅂ #가슴 #노브라',
#   '국내 최대의규모와안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #오또맘 #강인경 #슬롯사이트 #온라인바카라\n#이벤트진행중 #NCTLAB https://t.co/5j2dXEs4Bc',
#   '국내 최대의 규모와 안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인 https://t.co/f4Obc8rf9J',
#   '국내 최대의 규모와 안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인\n\n가입코드 j2019 가입코드 j2019\nhttps://t.co/IlRigcVFjT',
#   '국내 최대의 규모와 안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민평점 #토트넘 #우크라이나전쟁 #강인경 #슬롯사이트 #온라인바카라 #이벤트진행중 #bts #롤드컵 #카카오주식 #비트코인\n\n가입코드 j2019 가입코드 j2019\nhttps://t.co/IlRigcVFjT https://t.co/TiLA8eb9d1'],
#  ['https://t.co/T1Tm6Dvq2n\n#강인경 #보지살 #보지',
#   "[#강인경] let's take a shower https://t.co/MU8CbyZPSw",
#   '모델 원톱 몸매... 인정해야... https://t.co/nmnpmYDGkT #강인경 #인스타그램 #모델',
#   '#기무세딘\n#기무세딘사진 \n#라이키 \n#강인경\n#신재은\nhttps://t.co/edCLChxlo7 https://t.co/KGnLG6Qr5N',
#   'ㅇㅎ,webp)아침에 보면 좋은 가슴들\n\nhttps://t.co/6F0XRlYXy6\n\n#강인경 #노출 #속옷 #ㅎㅂ #셀카 #글래머',
#   'ㅇㅎ)살이라 빼라는 눈나\n\nhttps://t.co/ZkZFWtfuCY\n\n#강인경 #노출 #화보 #노브라 #노팬티 #니플 #ㅎㅂ #인증',
#   '"소녀시대 태연 같다" (네티즌 반응) https://t.co/quzkUrKkQF #강인경 #인스타그램 #모델',
#   'ㅇㅎ) 고추보집물\n\nhttps://t.co/7GNx3BiUxJ\n\n#ㅎㅂ #강인경 #고추보집물 #코스프레 #강사 #학생 #교사',
#   '#강인경 https://t.co/SSCjnUZwNq',
#   '#流量密碼 #正妹 #女神 #宅男女神 #網紅 #巨乳 #韓國 #강인경\n每日放送貼圖群 https://t.co/Z7cdfEEMwk\n\n韓國正妹강인경（卿卿）是知名的網紅，不只韓國人認識她...\n\nhttps://t.co/Kdf6ojxUxw https://t.co/OAZIb9LvyM',
#   '국내 최대의규모와안전을 자랑하는 라이브온 이벤트 진행중입니다.\n#토토홍보 #스포츠 #온라인카지노 #파워볼 #손흥민 #토트넘 #오또맘 #강인경 https://t.co/Ta7cnOoktf',
#   'https://t.co/umNireLGGi\n#강인경 좆네 #엉덩이',
#   '맥심 잡지 모델 강인경 비키니 아트그라비아 웹화보 몸매 로스트아크 97돌 인스타\n\n#맥심 #잡지 #모델 #강인경 #비키니 #아트그라비아 #웹화보 #몸매 #로스트아크 #97돌 #인스타\n\nhttps://t.co/qtzBjKxwKP',
#   '[#강인경] 내가 너의 버릇없는 여자친구가 되었을 때 https://t.co/q2ffLCuBhX'],
#  ['https://t.co/ocLT6uI8dQ\n노랑 #강인경 #뒤태 #팬티 #노출 #티팬티 #ㅂㅈ',
#   'https://t.co/jsWX0fdrXo\n푸짐하다 #강인경 #미니브라 #y존 #섹시걸 #섹시녀 #섹시 #팬티',
#   '#강인경 #inkyung97 #인경'],
#  ['작년에 작업했던 강인경님 사진 모작.\n재미있게 그렸던 기억이 난다.\n\n#강인경 #소녀 #일러스트 #페인팅 #드로잉 #캐릭터 #사진모작 #KangInkyung #Girl #Illustration #Painting #Drawing #Character #PhotoStudy #カン・インギョン #女の子 #イラスト #絵画 #図面 #キャラクター https://t.co/Fwd8JmGK4S'],
#  [],
#  ['원본 사진 수위 강력합니다... https://t.co/b6L3PoxBnv #강인경 #강인경노출 #코로나19',
#   'ArtGravia Vol.248 강인경\n#강인경,#ArtGravia,#Goddess247 https://t.co/qgSb89WRcO',
#   '[ArtGravia] vol.318 Kang Inkyung 강인경\n\nhttps://t.co/tY7t6103VV\n\n#Artgravia #inkyung97 #강인경 #idolmoe'],
#  ['#선물 주는 #강인경 #마이크로 #비키니 \nhttps://t.co/TCsd3HBUHf'],
#  ['[ArtGravia] vol.219 Kang Inkyung 강인경 #KangInkyung #강인경',
#   '[ArtGravia] vol.134 Kang Inkyung 강인경 [71P] #KangInkyung #강인경'],
#  ['과거에 올린 사진과는 비교조차 할 수 없을 정도로 파격적입니다 https://t.co/igFnVCpkZU #강인경 #강인경인스타그램 #인스타그램'],
#  ['강인경 비키니 화보\n\n#비키니 #섹트 #일탈 #야사 #코스프레 #화보 #모델 #강인경 #오프 #안구정화 #섹시 #섹시모델 \nhttps://t.co/GwDSNPHkVS',
#   '메시지 수준이... https://t.co/H4HY7XnLOh #강인경 #비난 #악플러',
#   '극후방주의 수능 응원..... https://t.co/mTj4JQF9Pj #수능응원 #강인경 #강인경인스타그램',
#   '#강인경 작가선생님\niyriver 은점토공예(아트클레이) 강사과정의 마지막\n작품이네요.\n이제 시험만 남았네요. ㅎㅎ\n올해 무언가를 성취한 기쁨이 더 큰 것 같군요.\n#은공예#은브로치#선물용브로치#아트클레이월드코리아 https://t.co/q4X9KjmY1x',
#   '맥심 멤버미 강인경 6K 영상 화보, 아찔한 수위! #맥심코리아 #맥림멤버미 #맥심 #강인경 #인플루언서 #sns #인스타그램\nhttps://t.co/SZEP6rJkLf',
#   "맥심 모델 출신 강인경, '아줌마가 야하고 못 생겨서...' 악플에 단호한 대처 #강인경 #맥심 #모델 #아트그라비아 #악플 https://t.co/2StLJpy4e4",
#   '이 정도면 의도적인 거 아닙니까??? https://t.co/KwWdnojb4n #강인경 #인스타그램 #강인경인스타',
#   '#강인경 풍만한 가슴으로 게임 홍보 https://t.co/XoLMRcwh16'],
#  ['"사기를 당했다"는 이들도 있었다고 https://t.co/At4mHCCLVt #강인경 #사진집 #오해',
#   '여친이 알면 크리스마스에 싸움 나니 조용히 보자 (@@같이 볼 친구는 소환) https://t.co/ZyYg32O0GA #크리스마스 #강인경 #산타',
#   '"더 예뻐졌다" https://t.co/OdYikxSAv1 #강인경 #모델강인경 #강인경인스타',
#   '#inkyung よりもっときれいな #スリジエ #英未希 おねえさん\n。\n。\n。\n。\n。\n。\n#강인경 보다 더 예쁜 #스리지에 #하나부사미키 누나\n@hanabusamikinpu https://t.co/MkftU6XL84',
#   '강인경 인스타 팩폭 댓글\n#강인경\nhttps://t.co/RQTuqhjmmo',
#   '"창피하지만 열심히 찍어"…맥심 모델 강인경, 게임에서 화보집 본다 #강인경\n\nhttps://t.co/rWvxYLMlB2',
#   '오직 강인경만이 할 수 있는... https://t.co/VIfyRiZhQQ #맥심 #강인경 #품절',
#   '"맥심 리미트는 여기까지" https://t.co/9X4kutzKzE #맥심 #강인경 #표지모델',
#   '#크리스마스, #강인경, #노출, #산타 \n  https://t.co/hpCHLD03oa',
#   '#강인경, 손가락급 #비키니…역대급 맥심 화보 https://t.co/bjXLO71Qd0',
#   "'인스타만 한다'…모델 강인경, 사칭계정+도용범에게 경고 날려 \n#강인경\nhttps://t.co/Zmb8dlIlAj",
#   '모델 강인경, 아찔한 바디라인 과시…“역대급이네” #강인경 #모델 https://t.co/9rz69gi4Rd https://t.co/DiSX7AwDpl',
#   '강인경 또 밑가슴 노출 아슬아슬 탱크탑! #강인경 #노출 #인플루언서 #sns #인싸\nhttps://t.co/exoRwN7ydO',
#   '"너무 행복해요" 맥심 모델 강인경, 완판녀 대열 합류 소감 #강인경 #맥심모델\n\nhttps://t.co/5C7mVv0KA9',
#   '#강인경 https://t.co/H8kVcgN4La',
#   "모델 강인경, '노출' 콘셉트로 맥심 표지 장식 #강인경 #모델 #노출 #미스맥심 #맥심\n#표지모델 #sns https://t.co/cq1PbhNeh0"],
#  ['리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/FmCNm9DeIJ',
#   'https://t.co/Y5tyyGKMfZ #강인경',
#   '게임하고 섹시화보 받아가자!!!\n#강인경 #모델 #게임 #모바일 #섹시\nhttps://t.co/qAetbEyGEu',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/kth9AsnzMz',
#   '이슈야 : #강인경, #맥심모델, #강인경악플https://t.co/2pj1rMoS96',
#   'https://t.co/Y5tyyGKMfZ #강인경 #섹시 #섹트',
#   'https://t.co/Y5tyyGtbor #강인경 #섹시화보',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 \n\nhttps://t.co/PjZW8TEMc2',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/tLrI8a4GXT',
#   '인스타에 야한 사진 올리면 생기는 일... https://t.co/canRlYHnTi #강인경 #맥심모델 #악플',
#   'https://t.co/xtHlWU9sSH #강인경 #섹시화보',
#   '게임하면 강인경 섹시화보 다준데!!!\n이걸로 뭐할꺼야???ㅋㅋ\n#강인경 #화보 #게임 #모바일\nhttps://t.co/jmHep28LSz',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/r6Qmw8C7WD https://t.co/tbHywv0rgC',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/gE9oslAW5K',
#   '이벤트 참여하면 강x경 섹시화보 전원증정!!! 게임만 하면되!! 서둘러~\n#강인경 #모델 #섹시 #화보 #모바일 #게임 #mmo\nhttps://t.co/jmHep1RatZ',
#   'https://t.co/wBQ3H5lzgx #강인경',
#   'https://t.co/Y5tyyGKMfZ #강인경 #섹시화보',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/7poaZ0OiIU',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/MbIVIDy0T1',
#   '아트그라비아 모델 강인경 ㄷㄷ\n#아트 #그라비아 #강인경 #모델\nhttps://t.co/4oxFSJOlQJ'],
#  ['리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/4Daz1WXhxu',
#   '섹시화보준데요ㅎ 같이게임해요ㅎ\n#강인경 #화보 #섹시 #모바일 #게임\nhttps://t.co/idsyoWDdrz',
#   'https://t.co/Y5tyyGtbor #리벤지오브술탄 #강인경',
#   'https://t.co/Y5tyyGKMfZ #강인경 #색시화보',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정!! 개꿀!! \nhttps://t.co/S00nmEoaEO',
#   '#강인경 섹시화보집 100% 전원 증정!!! 지금신청하세요\n#게임 #이벤트\nhttps://t.co/idsyoWDdrz',
#   'https://t.co/Y5tyyGKMfZ #강인경',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/6JOycOBv12',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정\nhttps://t.co/mOaD9xZ8jO',
#   'https://t.co/Y5tyyGKMfZ #강인경 #섹시화보 #리벤지오브술탄',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/7oXu9FJolg',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/fpnWtCmYIc',
#   '리벤지 오브 술탄 참여하고 강인경 화보집 받기\nhttps://t.co/qIncOzITbO\n\n#강인경 #강인경화보집 #리벤지오브술탄',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/p93xcCgFpc',
#   'https://t.co/wBQ3H5lzgx #강인경 #섹시화보',
#   '모델 강인경, 청초한 눈빛과 대비 이루는 몸매 공개…‘똘망똘망한 눈망울의 인경이’ \n#모델 #강인경 #아트그라비아 #리벤지오브술탄\nhttps://t.co/633HiHcWSj',
#   '#리벤지오브술탄 #이벤트 참여만해도 #강인경 #섹시화보 전원 #무료 증정ㅎ\nhttps://t.co/idsyoWDdrz',
#   'ㅋ 이게임 하면 섹시화보집 전원 다준다는데ㅋㅋ\n#화보 #게임 #강인경 #섹시\nhttps://t.co/idsyoWDdrz',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/tuMpBFWduf',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/d6vpNohVmj'],
#  ['https://t.co/Y5tyyGKMfZ\n#레이지오브술탄 #강인경 #섹시화보집',
#   'https://t.co/Y5tyyGKMfZ #라벤지오브술탄 #강인경',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/Bo0JgAACRp',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/JMZ3vqu124',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/y1lDZgAIOu',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/whA5PVHRQr',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/FkAP2Hy2JL',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/YB4EMCUusg',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/1sCgjQP2Op',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/f16nRlUIRV',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/Uxea6kBKHi',
#   '리벤지 오브 술탄 이벤트 참여하면 \n#강인경 섹시화보집 전원 무료 증정\nhttps://t.co/0GbONSiMtP',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/ammKyNKnDZ',
#   '#강인경 #섹시화보 #섹시화보집 #무료 #무료증정 #리벤지오브술탄 #이벤트 \n리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/CuQ09aU0E7',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/sGbrB50UYQ',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/yvdDLK9cf2',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/CSlgrkendC',
#   '#리벤지오브술탄 #이벤트 #강인경섹시화보집 \n리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정\nhttps://t.co/PJlPW0D4FJ'],
#  ['리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/ZBQ05C9yy2',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정\nhttps://t.co/6PDB9YUP3O',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정\n▶ https://t.co/7S9oPTEx0s\n이벤트페이지 속 전화번호 인증 후 다운로드 링크로 다운받으면 이벤트 참여 완료됩니다.\n리벤지 게임 튜토리얼의 재미도 느껴 보세요^^',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/HuEwM13Efz',
#   '와... 진짜 먹고싶어지는 영상..\n이런 영상에 한번 맛보면 중독이 된다\n\n◐https://t.co/11TeqSHDdm\n\n#핫팬츠쩍벌\n#움짤\n#ㄷㅐ한민국만ㅅㅔ\n#노ㅁㅗㅇㅑ동블로그\n#일반인ㄴㅗ출ㅅㅏㅇㅣ트\n#강인경\n#ㅇㅕ성섹ㅅㅣ란제ㄹㅣ망ㅅㅏ https://t.co/bbvdwhRESY',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/MvbOdf4SBL',
#   '서양 엉덩이 노출 영상 어디서 볼수있을까??\n고민말고 아래 확인해봐요!! 화끈 자료들만 있어요!!\n\n♥https://t.co/Ic8hTr4S01\n\n#한ㅊㅐㅇㅏ몸ㅁㅐ\n#오승ㅇㅏ맥심\n#설현레전ㄷㅡ움짤\n#레ㅇㅣ샤중국\n#ㅋㅏㄹㅏ강ㅈㅣ영\n#강인경\n#ㄱㅏ슴골에_손ㄱㅏ락_집ㅇㅓ넣ㄱㅣ https://t.co/iMBbgtq3d5',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/2F0nBGtSPv',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/pSdv4TRrtH',
#   '얼마전에 알았는데 완전 취향저격!\n화끈한 자료들이 많이있는곳\n\n♥https://t.co/oQweb1ntzj\n\n#ㅇㅏ프ㄹㅣㅋㅏㅌㅣㅂㅣ섹ㅅㅣbj\n#ㅇㅣ제는몸짱ㅇㅣㄷㅏ\n#ㅇㅕ인의음모\n#경북몸짱남만남후ㄱㅣ\n#강인경\n#ㅈㅣㄴㅏㅇㅏ찔한ㅂㅣㅋㅣㄴㅣ\n#ㄴㅗ출드레스 https://t.co/uPVqLMSaHC',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/tTrMjGMNok',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정!!\n클릭하셔서 구경한번 해보세요^^\n https://t.co/9ihm9vxtPQ',
#   '리벤지 오브 술탄 이벤트 참여하면 #강인경 섹시화보집 전원 무료 증정 https://t.co/ifDEi1JTbZ'],
#  ['와... 진짜 먹고싶어지는 영상..\n이런 영상에 한번 맛보면 중독이 된다\n\n♤https://t.co/nWECVK3dU2\n\n#김연정\n#엄상ㅁㅣ\n#ㄱㅐ그우먼허민\n#일본속옷화ㅂㅗ\n#일본ㅇㅖ능\n#암살교실영화\n#강인경 https://t.co/NSfGpSxhoJ',
#   '한 겨울에도 비키니를 입는\n곳이 있다고요? 한번 볼까\n\n♣https://t.co/aM05A2vhOf\n\n#ㄴㅗ출증ㅇㅕ고생\n#ㅇㅏ프ㄹㅣㅋㅏtv4ㄷㅐㅇㅕ신\n#ㅇㅣㅎㅏㄴㅣ맥심화ㅂㅗ\n#목ㄲㅏㅅㅣ전문\n#강인경\n#최신ㄴㅗ출영화\n#남ㅈㅏ섹ㅅㅣ한속옷 https://t.co/YlTPQuypOC',
#   '여자연예인 노출 모음 사이트추천해드림 아 또 봐야겠다\n\n◎https://t.co/c3r8jl56qN\n\n#식스밤소ㅇㅏ벌칙\n#섹ㅅㅣ화ㅂㅗㄴㅗ출\n#전소ㅁㅣ몸ㅁㅐ\n#홈쇼핑방송ㅅㅏ고레전ㄷㅡ\n#강인경\n#길거ㄹㅣㄱㅏ슴\n#ㄷㅏㄹㅣ벌ㄹㅣ고 https://t.co/MiTsilJ1BR',
#   '여자연예인 노출 모음 사이트\n추천해드림 아 또 봐야겠다\n\n♣https://t.co/1HVRmSJArB\n\n#초ㅇㅏ움짤속옷\n#유승옥몸ㅁㅐ\n#스칼렛요한슨화ㅂㅗ몸ㅁㅐ\n#강인경\n#ㅅㅣ노ㅈㅏㅋㅣㅇㅏㅇㅣ움짤\n#레ㅇㅣ싱모델순위\n#ㅇㅏ프ㄹㅣㅋㅏbj쏘 https://t.co/11nmh2bDIm',
#   '일본 그라비아 아이돌 자료 어디서 봐야할까??\n고민하지말고 아래 확인해봐요!! 화끈한 자료에요!!\n\n♂https://t.co/wfhAqEHB6D\n\n#ㅈㅐ밌는한국영화\n#중국레ㅇㅣ싱걸화ㅂㅗ\n#밤ㅂㅣ노은솔ㄹㅔ전드\n#안젤ㄹㅣㄴㅏㄷㅏ닐로ㅂㅏ\n#구ㅈㅣ성화ㅂㅗ\n#강인경\n#엠ㅋㅏ1위후보 https://t.co/1ZNftZL1gV'],
#  ['모델 강인경, 메이드복 차림의 화보 공개…“시선 둘 곳 없는 의상” #모델 #강인경 #메이드복 https://t.co/ydlZxWixt4',
#   '모델 강인경, 새롭게 공개한 화보 사진 눈길…“극강 섹시미 자랑하는 인경이” #모델 #강인경 https://t.co/HS2OlDEgEc',
#   '여자연예인 노출 영상 풀영상을 보고싶다면!!\n아래 화끈한 자료들만 모아뒀어요! 확인해봐요!!\n\n￥https://t.co/o7xNyGS3QP\n\n#ㅇㅣ수ㅇㅏㄴㅗ출ㅇㅣ신\n#동상ㅇㅣ몽ㄴㅗ출광웹툰\n#섹ㅅㅣ란제ㄹㅣ룩\n#섹ㅅㅣ댄스ㅇㅏ프ㄹㅣㅋㅏtv\n#강인경\n#그ㄹㅏㅂㅣㅇㅏ모델일본\n#ㅇㅕㅈㅏ목욕ㅎㅏ는동영상 https://t.co/viXEWXPAvg',
#   '#EunGG : #모델 #강인경 #섹시 #은꼴  https://t.co/O9hG76pdcQ',
#   '모델 강인경, 비키니 입고 환상적 바디라인 과시…“인경님이 최고” #모델 #강인경 #비키니 https://t.co/rbxH7sB92B',
#   '모델 강인경, 만화같은 비현실적 몸매 뽐내…“사랑스러운 인경이” #모델 #강인경 https://t.co/yNvofjjOIZ',
#   '모델 강인경, 새로운 화보사진 공개…“솜뭉치 위에서 매력 발산하는 인경이” #모델 #강인경 https://t.co/cT937giS8E',
#   '연예인 노출 움짤 볼수있는곳 없을까요??\n찾아다니지말고 아래 확인해봐요!!\n\n▩https://t.co/0M5y20ANFb\n\n#양정원몸ㅁㅐ\n#전효성레전ㄷㅡ\n#귀ㅇㅕ운움짤ㅁㅗ음\n#aoa초ㅇㅏ움짤\n#김천ㅅㅣㄷㅐ딸방강추\n#강인경\n#조ㅅㅔ희레ㅇㅣ싱걸 https://t.co/2ERM4iNSqa',
#   '모델 강인경, 새로운 란제리 화보 공개해 눈길…“귀엽고 섹시한 윙크 메롱 콤보” #모델 #강인경 https://t.co/i6KwpUrRnU',
#   '모델 강인경, 화보 촬영 중 찍은 사진 눈길…“아찔한 인경이 몸매” #모델 #강인경 https://t.co/WADQT2982i',
#   '모델 강인경, 토끼모자 쓰고 상큼美 폭발…“나도 이거 해보고 싶었어” #모델 #강인경 #토끼모자 https://t.co/hOjhDASe48',
#   '모델 강인경, 남심 저격하는 화보 공개…“순간 심멎하는 줄” #모델 #강인경 https://t.co/bKVHOz7T9F',
#   '여자연예인 노출 모음 사이트\n추천해드림 아 또 봐야겠다\n\n○https://t.co/Dz7scgwVKN\n\n#초ㅇㅏ움짤속옷\n#ㅊㅐ수빈몸ㅁㅐ\n#화ㅂㅗ천ㅈㅐ\n#일본av슴ㄱㅏㄴㅗ출\n#강인경\n#금발ㅇㅕㅈㅏ거ㄱㅣㅅㅏ진\n#ㅇㅕ성섹ㅅㅣ란제ㄹㅣ망ㅅㅏ https://t.co/Hes1HyccBn',
#   '#EunGG : #강인경 인상적인 #뒤태 https://t.co/i5rn4lQGu2',
#   '이건조금 과한데..? 과한노출 볼수있는곳!!\n아래에서 확인! 가장 화끈한 자료들만 모았어요!!\n\n★https://t.co/hByn0sXYeB\n\n#일본그ㄹㅏㅂㅣㅇㅏ모델순위\n#bjㅇㅣ요\n#짤방\n#ㅋㅣ스ㅌㅣㅂㅣ\n#ㅇㅕ민정ㄱㅏ슴\n#ㅇㅏ줌ㅁㅏ보ㄱㅣ뒤ㅌㅐㅅㅏ진\n#강인경 https://t.co/f0sTCiUayo',
#   '모델 강인경, 토끼모자 쓰고 상큼美 폭발…“나도 이거 해보고 싶었어” #모델 #강인경 #토끼모자 https://t.co/bSdB2PKl5s'],
#  ['모델 강인경, 볼륨감 넘치는 몸매로 섹시화보 촬영…“차세대 베이글녀”\n\n#강인경 #모델 #섹시\n\nhttps://t.co/pTU57swpXk',
#   '모델 강인경, 동물 잠옷 입고 근황 공개…“바깥 세상아 기다려랏” #강인경 #모델 #동물잠옷 https://t.co/ZaUkY36Adw',
#   '모델 강인경, 방바닥에 누워서 찍은 셀카 눈길…“머리 묶으니까 더 이쁘네” #강인경 #모델 https://t.co/D3ME6fcDOr',
#   '모델 강인경, SNS서 전한 근황 눈길…“아 5분만 쉴게” #강인경 #모델 https://t.co/BYOCyZVOCQ',
#   '#인스타그램 #강인경\n\n인스타그램스타.강인경(@inkyung97) https://t.co/jpqeiTdi3t',
#   'Inkyung \nIg : https://t.co/N3CPgJPboY\n#강인경\n#inkyung97\n#koreangirl \n#shorthairgirl \n#TeamShortHair https://t.co/8bqYAKB9q3',
#   '모델 강인경, 일상 사진 공개해 눈길…“지금까지 중 제일 이쁘네” #강인경 #모델 https://t.co/oWnUE8GOsT',
#   '모델 강인경, 메이드복 차림의 화보 공개…“시선 둘 곳 없는 의상” #모델 #강인경 #메이드복 https://t.co/LoWZLxyi5i',
#   '모델 강인경, 휴식시간에 찍은 셀카 눈길…“내 사랑은 어디에” #강인경 #모델 https://t.co/r1DHN57nCr',
#   '모델 강인경, 휴식시간에 찍은 셀카 눈길…“내 사랑은 어디에” #강인경 #모델 https://t.co/8ZTCQLw9XL',
#   '#LottoHitMe   : #모델 #강인경 https://t.co/dwAYNFswFR',
#   '모델 강인경, 아찔한 바디라인 과시…“역대급이네” #강인경 #모델 https://t.co/T1FtF0kmqs',
#   'LOTTO HIT ME: #모델 #강인경 https://t.co/dwAYNFswFR',
#   '모델 강인경, 화보 촬영 중 셀카 삼매경…“심쿵하게 하는 반전 몸매” #강인경 #모델 https://t.co/vdufyDwIWM',
#   '트위치TV 스트리머 마루에몽, 모델 강인경과 쌍둥이같은 투샷…‘글래머들의 만남’ #트위치TV #마루에몽 #강인경 https://t.co/cxBPwqLjxd 부자연권 스러워',
#   '모델 강인경, SNS서 전한 근황 눈길…“아 5분만 쉴게” #강인경 #모델 https://t.co/InLjARvQ5A',
#   'Inkyung \nIg : https://t.co/N3CPgJxA0o\n#강인경\n#inkyung97\n#koreangirl \n#shorthairgirl \n#TeamShortHair https://t.co/5TdmQNGpZd',
#   '모델 강인경, ‘일하는 세포’ 혈소판 코스프레 눈길…“겨울에도 열일하는 인경이” #강인경 #모델 #일하는세포 #혈소판 https://t.co/eZq1ihPurt',
#   '트위치TV 스트리머 마루에몽, 모델 강인경과 쌍둥이같은 투샷…‘글래머들의 만남’ #트위치TV #마루에몽 #강인경 https://t.co/W7DCMslLt2'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# # 메모 .. (추후 구현되어야할 사항 등)
# ## db서버 구축하기
# ## 수집시간이 너무 오래 지나는 경우...
# ## textlist를 페이지 크롤링시마다 db에 옮겨 담기!!
# ## csrf와 같은 값은 cookie의 ct0에 존재하는데, 이는 beautifulsoup로 input type hidden에서 찾아내야한다. 현재는 없어도 돌아가는 것으로 보임.
# ## 자연어분석 떄 -> 반복되는 도배 콘텐츠에 대해서는 어떻게할지? (가령, 고대 검색 -> 윤석열 퇴치운동)
# ## 특히 인스타그램도 마찬가지로,, 애초에 컨텐츠자체가 적거나(가령, 지능정보), 전혀 검색결과가 나오지 않는경우?
# ## banned hashtag인 경우, 이진 탐색과같은 방법으로 사전순으로 정렬된 banned hashtag에 존재하는지 검색할 수 있을것같다.-> 허나 일시 검열도 존재하고 구체적으로 어떤 해시태그가 밴되는지는 정확하게 알 수 없음.

# %% [markdown]
# # 현재까지 예외처리된 사항 (22.11.07 기준)
#
# ## 컨텐츠자체가 수집목표보다 부족하거나, 전혀 검색결과가 나오지 않는경우,
# ## banned hashtag -> 리턴 형식은 정확하지만 tweets값이 비어있음. (다음 커서는 존재하므로 계속 넘어감) : 이 경우 더 안넘어가고 멈추게 예외처리. //oppa같은 경우 컨텐츠 개수가 페이지당 0개는 아니지마 1개, 2개 인걸로 보아 일부 검열되고 있는것으로 보임. 이 경우 페이지당 컨텐츠개수가 0개인 페이지가 5개 연속으로 발생하는 경우 멈추도록 조치검열되는 것으로 보이는 해시태그들에대한 예외처리 -> 빈 페이지가 5번 이상 연속해서 나올 경우 유의미한 데이터가 없는 것으로 판단, 함수 종료
# ## 이외의 부분에 대해 try-except 적용 (json내부에서 error로 리턴되는경우(가령 검색어가 없는 경우 등), json내부가 비어있는경우 등...)
