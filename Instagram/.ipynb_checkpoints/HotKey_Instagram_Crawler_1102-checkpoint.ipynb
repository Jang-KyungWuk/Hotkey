# %% [markdown]
# # 남은 작업 : 예외처리(try-except, 예외시마다 로그인 계정바꾸기)
# # 크롤링 중 예외발생시 작업 저장, 매 요청시마다 딜레이 다르게 주기**

# %% [markdown]
# # 리트라이하는 로직 완성하기
# # '안성기러기러기' 같이 검색결과가 없는 키워드 같은 경우..?
# # 'CardiB'와 같이 검색결과가 인기게시물밖에 없는경우-> 인스타그램 자체에서 인기게시물만 반환하고 잇음
# # 밴먹은 해시태그 리스트 만들어놓고 예외처리로 관리하기

# %%
#try except 이용한 예외처리
#sleep함수 이용해서 매 요청마다 딜레이 다르게 주기

# %%
from requests import get, post, Session
from urllib import parse
import json
from datetime import datetime

# %%
def login(id, pw, headers, session):
    resp = session.get('https://www.instagram.com/data/manifest.json', headers=headers)
    headers['x-csrftoken'] = session.cookies.get('csrftoken')
    url = 'https://i.instagram.com/api/v1/web/accounts/login/ajax/'
    params = {
        'enc_password': None,
        'username': None,
        'optIntoOneTap': 'false'
    }
    params['username'] = id #id
    params['enc_password'] = '#PWD_INSTAGRAM_BROWSER:0:{}:{}'.format(
    int(datetime.now().timestamp()), pw)   # PW
    resp = session.post(url, data=params, headers=headers) #로그인 요청
    if(resp.status_code != 200):
        print('\nlogin response error : retrying with other accounts...\n\n')
        print(resp.text)
        return (headers, session, False)
    print('\nsuccessfully logged in...')
    return (headers, session, True)

# %%
def hot_key_instagram_top(query, headers, session, max_page=5):
    before = datetime.now()
    top_list = [[] for i in range(max_page)]
    
    url = 'https://i.instagram.com/api/v1/tags/web_info/?tag_name={}'.format(parse.quote(query))
    headers['x-csrftoken'] = session.cookies.get('csrftoken') #재설정
    resp = session.get(url, headers = headers)
    if(resp.status_code != 200): #응답 에러
        print('response error during crawling : please retry with some other way\n')
        print(resp.text)
        return (False, top_list) #계정바꿔서 재시도
    
    #첫페이지 응답 정상인경우
    resource = resp.json()
    
    #top 게시물 돌기
    print('인기 게시물: 1페이지....')
    for i in resource['data']['top']['sections']: #0~8
        for k in i['layout_content']['medias']:
            if (k['media']['caption'] != None):
                if 'text' in k['media']['caption'].keys():
                    top_list[0].append(k['media']['caption']['text'])

    #top기준 다음 페이지 관련 정보
    top_info = {'top_max_id':'', 'top_page': '', 'top_isnext': False}
    if resource['data']['top']['more_available']:
        top_info['top_max_id'], top_info['top_page'], top_info['top_isnext'] = \
        resource['data']['top']['next_max_id'], resource['data']['top']['next_page'], True
    
    #그 다음 페이지부터 돌기
    url = 'https://i.instagram.com/api/v1/tags/{}/sections/'.format(parse.quote(query))
    data = {'max_id': top_info['top_max_id'], 'page': top_info['top_page'], 'surface' : 'grid', 'tab': 'top'} #tab을 top으로 변경
    
    while (top_info['top_isnext']==True and data['page']<max_page):
        headers['x-csrftoken'] = session.cookies['csrftoken'] #매번 재설정해주기
        resp = session.post(url, data=data, headers=headers)
        resource = resp.json()
        print('인기 게시물: {}페이지....'.format(data['page']+1))
        for i in resource['sections']: #0~8
            for k in i['layout_content']['medias']: #0~2
                if (k['media']['caption'] != None):
                    if 'text' in k['media']['caption'].keys():
                        top_list[data['page']].append(k['media']['caption']['text'])
            
        if resource['more_available']:
            data['max_id'] = resource['next_max_id']
            data['page'] = resource['next_page']
    
        else:
            top_info['top_isnext']=False
    
    print('인기 게시물 수집 완료!\n')
    print('총 소요시간 : ', datetime.now() - before,'\n\n')
    return (True, top_list)

# %%
def hot_key_instagram_recent(query, headers, session, max_page=5):
    before = datetime.now()
    recent_list = [[] for i in range(max_page)]
    
    url = 'https://i.instagram.com/api/v1/tags/web_info/?tag_name={}'.format(parse.quote(query))
    headers['x-csrftoken'] = session.cookies.get('csrftoken') #재설정
    resp = session.get(url, headers = headers)
    if(resp.status_code != 200): #응답 에러
        print('response error during crawling : please retry with some other way\n')
        print(resp.text)
        return (False, recent_list) #계정바꿔서 재시도
    
    #첫페이지 응답 정상인경우
    resource = resp.json()
    
    #recent 돌기
    print('최근 게시물: 1페이지....')
    for i in resource['data']['recent']['sections']: #0~8
        for k in i['layout_content']['medias']:
            if (k['media']['caption'] != None):
                if 'text' in k['media']['caption'].keys():
                    recent_list[0].append(k['media']['caption']['text'])
    #recent기준 다음 페이지 관련 정보
    recent_info = {'max_id':'', 'page': '', 'isnext': False}
    if resource['data']['recent']['more_available']:
        recent_info['max_id'], recent_info['page'], recent_info['isnext'] = \
        resource['data']['recent']['next_max_id'], resource['data']['recent']['next_page'], True
        
    #그 다음 페이지부터 recent 돌기
    url = 'https://i.instagram.com/api/v1/tags/{}/sections/'.format(parse.quote(query))
    data = {'max_id': recent_info['max_id'], 'page': recent_info['page'], 'surface' : 'grid', 'tab': 'recent'}

    while (recent_info['isnext']==True and data['page']<max_page):
        print('최근 게시물: {}페이지....'.format(data['page']+1))
        headers['x-csrftoken'] = session.cookies['csrftoken'] #매번 재설정해주기
        resp = session.post(url, data=data, headers=headers)
        resource = resp.json()
        for i in resource['sections']: #0~8
            for k in i['layout_content']['medias']: #0~2
                if (k['media']['caption'] != None):
                    if 'text' in k['media']['caption'].keys():
                        recent_list[data['page']].append(k['media']['caption']['text'])
            
        if resource['more_available']:
            data['max_id'] = resource['next_max_id']
            data['page'] = resource['next_page']
    
        else:
            recent_info['isnext']=False
    
    print('최근 게시물 수집 완료!\n')
    print('총 소요시간 : ', datetime.now() - before,'\n\n')
    return (True, recent_list)

# %%
def print_text(text_list):
    for i in range(len(text_list)):
        print('\n\n\n\n\n\n################################{}페이지##########################################################################\n\n\n'.format(i+1))
        for k in text_list[i]:
            for j in k.splitlines():
                if len(j)>0:
                    print(j)

# %%
#MAIN---------------------------------------------------------------
keyword = 'cardib'
# 초기값 선언
login_success = False
total_success = False
acc_list = [('kj10522002@korea.ac.kr','devdev123'),('quickpass8@gmail.com','thskrl1!'),('hotkey2','gktzl2'),
           ('lshyun0510.11@gmail.com', '*thvmxmdnpdj'), ('seungirumd+1@gmail.com', 'pinstaw24')] #lshyun0510.dev@gmail.com / *thvmxmdnpdj (성현님 예비 id/pw)
cur_idx = -1 #현재 사용하고 있는 아이디 인덱스
max_page = 3
top_list, recent_list = list(), list()
#초기값 설정 끝

# %%
while not total_success: #크롤링 성공까지 돌아가면서 시도
    cur_idx = (cur_idx+1)%len(acc_list) #원형 순환
    before = datetime.now()
    while not login_success: #로그인 성공까지 돌아가면서 시도
        print('Currently trying with ... :', acc_list[cur_idx][0]) #현재 로그인 시도 중인 계정
        session = Session()
        headers = dict()
        headers['user-agent'] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.24'
        headers['x-ig-app-id'] = '936619743392459'
        headers, session, login_success = login(acc_list[cur_idx][0], acc_list[cur_idx][1], headers, session)
    print('로그인 소요시간 : ', datetime.now() - before, '\n')
    login_success = False
    #로그인 성공인경우// 현재 cur_idx는 로그인 진입 성공한 계정 인덱스
    print('Maximum number of pages to crawl : ', max_page, '\n\n')
    total_success, top_list = hot_key_instagram_top(keyword, headers, session, max_page)
    #or
    total_success, recent_list = hot_key_instagram_recent(keyword, headers, session, max_page)

total_success = False
# Out:
# Currently trying with ... : kj10522002@korea.ac.kr
#
# successfully logged in...
# 로그인 소요시간 :  0:00:03.388810
#
# Maximum number of pages to crawl :  3
#
#
# 인기 게시물: 1페이지....
# 인기 게시물: 2페이지....
# 인기 게시물: 3페이지....
# 인기 게시물 수집 완료!
#
# 총 소요시간 :  0:00:06.726366
#
#
# 최근 게시물: 1페이지....
# 최근 게시물 수집 완료!
#
# 총 소요시간 :  0:00:01.606399

# %%
top_list, recent_list
# Out:
# ([['RIP Take Off 😔💔 Sending prayers to his family & friends. May his legacy live forever! 🙏\nFollow @iamcardib_edits',
#    '😢🙏🏾, I’m praying for @offsetyrn & @quavohuncho. Good or bad terms. Takeoff this can’t Be TRUE?!!💔💔 life To short. Dats exactly why y’all didn’t see me bashing Migos.🥺 they still a Fucking family!\n\n#cardib  #bardigang #fanpage #fanlove #viral #instagram #muchlove #explore #cardidifferent #watch #grammys #2022 #followforfollowback #lit #bronx #nyc  #babykulture #goals #goodvibes #goodmorning  #newzealand #jamaica #ghana  #worldwide #orlando',
#    'What 19 looks like omg🙈🖤\nThrow back 😩\n-\n-\n-\n-\n-\n-\n\n#popsmoke #lilpump #Takeoff  #DrinkChamps \n#lilbaby #dababy #drake #rap #liluzivert #nbayoungboy #lildurk #hiphop #gunna #music #youngthug #travisscott #rapper #migos #juicewrld #future #beats #polog #migos #cardib #kodakblack #nlechoppa #moneybaggyo  #meekmill #nickiminaj #djkhalil',
#    'Fans are speaking out about the tragic incident involving Takeoff. What are your thoughts on this⁉️ Visit our profile for more‼️\n\nFollow us @hiphopquoteroom to stay connected\n\n📸 @yrntakeoff',
#    '#India and #LilDurk were together for willows birthday party.',
#    "Kirshnik Khari Ball better known as #Takeoff has reportedly passed away at the young age of 28 🕊️\n\nAfter an incident early this morning in Houston stemming from an argument, famous Migos member @ unfortunately passed 💔\n\nIt's crazy this keeps happening, and these young artists are losing their lives at such young ages.\n\nReminiscing some past memories & music, I included one of my favorite funny moments along with a few snippets from his music. I also included an in-depth video @syspence_ made on Takeoff, along with a childhood photo with Quavo. \n\nSending my condolences to his family, friends and other loved ones. Long Live Takeoff 💔🙏🏼\n-\nLike, Comment, Save & Share ❤️\u200d🩹\nFollow @loadingunderground",
#    '#rip Takeoff you are and will always be missed 🙏🏻❤️ sending love and prayers 💕',
#    '4 years ago today, #Takeoff dropped his only solo album “The Last Rocket” 🚀🙏\n\nRest in peace, Takeoff 🕊💔\n\n• Follow @whatsonrap For More Daily Content ✊🏼\n_\n•Follow @whatsonrap For More ⚡️\n\n•Follow @whatsonrap For More ⚡️\n_',
#    '#Drake speaks on #Takeoff’s passing 🙏❤️\n\nFollow @rnsszn for more!🚀☑️\n\n#hiphop #rap #nickiminaj #explorepage #cardib #liluzivert #lilbaby #travisscott #kanyewest #rapper #explore #lilwayne #beyonce #dababy #migos #ovo #meekmill #future #trap #rihanna #jayz #youngthug #nbayoungboy #viral #beats #rnsszn #riptakeoff',
#    '#Gillie slams people who record horrific events instead of letting people mourn 😮👏🏾\n\nFollow @ratingsgamemusic for more #RGMNews',
#    'According to reports, #Takeoff of #Migos was shot and killed early this morning in Houston. Several sources are reporting he was shot over a dice game gone wrong. Takeoff was 28. Our deepest condolences go out to his family and friends. #riptakeoff \n(Via @worldstar )',
#    '#Gillie speaking facts? #Takeoff',
#    '#Takeoff dropped his only studio album "The Last Rocket" 4 years ago today 💿🕊 Favourite song ? 💭🚀',
#    "📸: Takeoff from rap group Migos is confirmed d*ad at the age of 28 after being sh*t in Houston. Rest in Peace 🙏\nFollow Us For More: @hiphopofthe90s🔥\nDon't forget to turn on our post notifications 🔌"]],
#  [[], [], []])

# %%
print('인기게시물 출력 : ')
print_text(top_list)
# Out:
# 인기게시물 출력 :
#
#
#
#
#
#
# ################################1페이지##########################################################################
#
#
#
# 둘 다 첫 고연전🐯🐯
# .
# .
# .
# #고연전 #연고전 #고려대 #서울 #대학생 #l4l #f4f #fff #like4likes #팔로우 #맞팔 #좋반 #좋아요반사 #고려대학교 #연세대학교 #고양
# 즐거운 고연전 날에🎶
# #고려대 #고연전 #압승
# 퍼스널 컬러❤️ #고연전 #고려대학교
# 당신에게 세계를,
# 2021.
# 현영
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# #출근전업로드
# A Night to Remember 🔴⚫️⚪️
# .
# .
# .
# .
# .
#  #KoyeonClassic #Descente #고연전 #정기전 #빙구 #아이스하키 #포카리스웨트 #데쌍트 #62
# #2022정기고연전 #야구
# 20221028 / 잠실야구장
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 너에겐 가장 예쁜 모습만 보여주고 싶어서.
# 2021.
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 택시에서 잠들기 전에 셀카 찍은것도 웃기고
# 못깨서 경찰온것도 웃기고
# 그 와중에 집가서 셀카 더 찍은게 어이가없다
# #고연전 #고대승 #안암 #ootn #22학번 #새내기
# 학교에서 벗어나지 못한 휴학생과
# 없던 고뽕 강제 생성 중인 3학년
# #고려대 #고연전 #체육국 #야구장 ❤️
# 늦은 고연전 인증
# Photo by @jjun_howoo
# #즐거운 #고연전 #날에 #연대생 #우는소리
# 호랑이는 독수리를 찢어ㅋ #고연전
# 첫 고연전 압승... 3년뒤에 보자...
# 아니 내년에도 볼 수 있으면 좋겠네😢
# #고연전 #고연전2022 #고연전승리 #필승전승압승 #민족의아리아 #민족고대 #고려대 #고려대학교
# 🙋예비 고대생들 손🙋
# ⠀
# 아무도 물어보지 않았지만
# 고려대의 15가지 TMI를
# 뫁뫁위키가 알아서 잘, 딱,
# 깔끔하고 센스있게 정리해봤어요📝
# ⠀
# "너 알고 있었어?🤔"
# 고려대의 흥미로운 사실들을
# 친구를 태그해 알려주세요!
# ⠀
# 다른 학교, 다른 주제의 TMI도 알고 싶다면
# 댓글로 남겨주세요💬😏
# ⠀
# 𝙬𝙬𝙬.𝙢𝙤𝙩𝙚𝙢𝙤𝙩𝙚.𝙠𝙧
# ⠀
# #모트모트 #motemote #고려대학교 #고려대 #연세대 #연고전 #고연전 #고려대생 #고려대캠퍼스 #고그와트 #공스타그램 #공스타 #공스타소통 #공부자극 #자극 #공부스타그램 #대학정보 #새내기 #대학 #대학생 #대학교 #다람쥐길 #고대안암 #공부인증 #공부기록 #꿀잼 #유머 #꿀팁 #과몰입 #tmi
# 연대생 우는 소리~🤣
# #고연전
# 연차내고 #오대빵 보러옴
# #고연전 #야구
# #고연전
# #멋지다아들
# #이기자홧팅
# #고연전응원중
# K 🐯❤️ #고연전
# #필승전승압승 #고연전
# ⠀
# ❤️고연전룩
# ⠀
# 졸업한지 5년이 다되어가는 교우지만
# 3년만에 열린 고연전 못참고 달려갔다는🐶
# (연고전 태클 오늘만은 안받습니다ㅎㅋ)
# ⠀
# 그 와중에 안입은지 너무 오래돼서
# 가죽이 삭아버린 검은색 과잠바,,,
# 급하게 챙겨 나왔는데 도착하고 나서야
# 가죽이 가루가 되어 떨어지는 상태를 파악하고
# 입 댓발 내밀며 결국 버렸네요🥲😭
# ⠀
# 고연전은 최종으로 고대가 3:2로 이겨서
# 재학생들은 불토를 보내겠네요!
# 할미는 집에와서 휴식합니다🥱
# ⠀
# 다들 즐거운 토요일 보내셨길!❤️💙
# 고대가 이기는걸 다 보네~
# .
# 이겼다아~!!😆🙌
# #고연전 #잠실종합운동장 #종합운동장 #잠실 #follow #followback #likeforlikes #lfl #f4f #follow4like #l4f #lfl #likeforlikes #like4like #연고전
# ㅋㅋㅋㅋ연데가 연대밖에 없었댘ㅋㅋㅋ
# .
# .
# .
# #엄지렐라 #엘리트 #연세대 #연대 #연고전 #고연전 #고대 #고려대 #하버드 #교환학생 #연극영화과 #모교 #대학교 #개그 #개그우먼 #유머 #유머스타그램 #유머저장소 #예능 #좋반 #좋아요반사 #좋아요 #선팔하면맞팔 #선팔 #맞팔 #팔로우 #꿀잼
# 3년 만에 열리는
# ‘2022 정기 고연전’
# 대부분의 재학생에게 처음인 ‘2022 정기 고연전’은 그래서 어느 때보다 뜨겁고, 간절한 기다림이었습니다~
# 5개 운동부 주장의 각오와 함께
# 필승! 전승! 압승!
# #고려대#고연전#정기전#야구#농구#럭비#축구#아이스하키
# #고연전 D-3
# 참살이길 현수막
# #고려대학교응원단 #고려대 #고대
# #고연전 #정기전 #필승전승압승
# #잠실야구장#고양농구장#목동빙구장
# #고양종합운동장
# #참살이길 #안암
# 나의 고대 오늘도 필승, 전승, 압승입니다❤️🏀
# #고연전

# %%
print('최근게시물 출력 : ')
print_text(recent_list)
# Out:
# 최근게시물 출력 :
#
#
#
#
#
#
# ################################1페이지##########################################################################
#
#
#
# 고연전🐯너무나 소중한 추억
# #고연전 #고려대학교 #승리
# You know you had a good time when 민족의 아리아 is ringing in your ears when you try to sleep
# #고연전 #고연전🐯
# 진지하게 ,, 연대 응원이 .. 재밌어요 .. ?
#  - 고연전 2일차
# 안되겠다 너무 재밌따 졸업해도 가야겠뎌🫢🐯❤️‍🔥❤️‍🔥
# #고연전 #필승전승압승 #이겨버림
# 빨리
# 오라
# .
# .
# .
# #주말
# #정기전
# #고연전
# #연고전
# #럭비
# #2022정기고연전 #주경기장 #럭비 #축구
# 20221029 / 고양종합운동장
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 주말 강원도 1박2일 투어
# 버치힐 그리고 알펜시아
# 너무 좋은 구장에서 좋은 분들과 고연전 대결
# #골프 #골프스타그램 #벤처기업 #청년사업가 #이노비즈 #메인비즈 #경치가예술 #버치힐cc #알펜시아cc #날씨좋다 #가을골프 #golf #사업가 #싱글치고싶다 #무기명 #회원제 #고연전 #1박2일골프
# 🐯막학기 고연전은 행복하고 잊지 못할 추억이 될 것임❤️
# #고연전 #고려대 #고려대학교 #연세대 #연세대학교
# #고연전 때 발급받은 버미 #nft
# 황금호랑이도 있다고하는데 괜히 가지고싶다
# '1인1개 한정'이라 희소성때문에 그렇겠지
# 멋있어! 멋있는 학생들이다
# #일상 #좋아요 #좋반 #오오티디 #여행 #유머 #꿀잼 #정보 #팔로우반사 #공감 #강아지 #남자 #여자 #고양이 #휴식 #휴가 #음식 #고대 #안암 #에타 #인류애 #충전 #청소 #연고전 #고연전 #쓰레기 #호잇쨈
# 늦은 고연전 인증
# Photo by @jjun_howoo
# #즐거운 #고연전 #날에 #연대생 #우는소리
# 22.10.28~29 고연전!
# 새내기 때 한 번도 못이겼는데 드디어 이겼다ㅎ..
# 준비하는데 많은 도움을 주신 yt현단원, 기획진, 오비분들, 동작부, 엘리제 분들 모두 수고 많으셨습니다!!
# 내년에도 필승 전승 압승!!!
# #고연전 #필승전승압승
# SPARTAN-LADY ICEHOCKEY TEAM
# 수요일 21:00-22:30
# 토요일 20:30-22:00
# 11월 5일, 12일 체험 자리 남았습니다~!
# - 정식 팀원 모집중💜
# - 체험 문의는 상단 링크 클릭👆🏻😀
# spartanicehockey_lady
# #스포츠
# #운동하는여자
# #하키
# #하키맘
# #하키스타그램
# #하키선수
# #아이스하키
# #고려대학교
# #아이스하키레슨
# #하키레슨
# #하키꿈나무
# #운동하는여자
# #여자운동
# #고연전
# #하남아이스박스
# #연고전
# #원데이클라스
# #빙구
# #정기전
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# #출근전업로드
# 쀠로리페어리 혀노쓰 ㅋ
# 첫 #고연전
# 우리의 함성은 신화가 되리라 🐯
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 어 잘 놀았다~
# #고연전
# 쉿하고 꿇어라 연세🦅 고연전은 고대가 우세🐯
# .
# .
# #고려대학교 #정기전 #고연전 #고연전2022
# 지난 주말 다녀온 연고전 포스팅
# 즐거웠습니다🙂
# 대학원생 할비 잘 챙겨주신 YCC 여러분께 무한 감사😌
# KUCC분들도 너무 즐거웠고, 마지막에 만난 이름 모를 고대분들도 즐거웠습니다🙂🙂
# #연고전 #고연전
# 학교에서 벗어나지 못한 휴학생과
# 없던 고뽕 강제 생성 중인 3학년
# #고려대 #고연전 #체육국 #야구장 ❤️
# we are young tigers🐯 #고연전
# [2022 고연전 : 농구]
# 고려대학교 농구부
# ----------------------------------------
# #고연전 #연고전
# #야구 #빙구 #농구 #럭비 #축구
# #고려대학교응원단
# #연세대학교응원단
# #고려대 #연세대 #친선
# 너무너무행복행🫶🏻💃🏻
# -
# #할로윈 #할로윈파티 #인생네컷 #인생 #사진 #행복 #고연전 #연고전 #halloween #party #friends #photooftheday
# 2022 할로윈 코스튬은 고연전 복장으로❤️‍🔥
# -
# #할로윈 #할로윈파티 #고연전 #연고전 #고려대 #halloween #happy #halloweencostume #party #korea
# [2022 고연전 : 1일차]
# 2022 고려대학교응원단 음악부
# 엘리제
# ----------------------------------------
# #고연전 #연고전
# #야구 #빙구 #농구 #럭비 #축구
# #고려대학교응원단
# #연세대학교응원단
# #고려대 #연세대 #친선
# [2022 고연전 : 농구]
# 레파토리 응원
# 2022 고려대학교응원단 부단장
# 노은서
# ----------------------------------------
# #고연전 #연고전
# #야구 #빙구 #농구 #럭비 #축구
# #고려대학교응원단
# #연세대학교응원단
# #고려대 #연세대 #친선
#
#
#
#
#
#
# ################################2페이지##########################################################################
#
#
#
# [2022 고연전 : 농구]
# 2022 고려대학교응원단 신입단원
# 김시현
# ----------------------------------------
# #고연전 #연고전
# #야구 #빙구 #농구 #럭비 #축구
# #고려대학교응원단
# #연세대학교응원단
# #고려대 #연세대 #친선
# [2022 고연전 : 농구]
# 2022 고려대학교응원단 신입단원
# 김서연
# ----------------------------------------
# #고연전 #연고전
# #야구 #빙구 #농구 #럭비 #축구
# #고려대학교응원단
# #연세대학교응원단
# #고려대 #연세대 #친선
# 💙🦅⚽️
# .
# .
# .
# #연고전 #고연전 #🦅 #🐯 #⚽️ #⚾️ #피어나라연세여 #떠킥
# IC hockey coach
# 김상원
# 광운초 - 경희중 - 선덕고 - 연세대
# 빠른스피드와 센스있는 하키 플레이
# 3년만에 고연전 🐯 이겼다~
# .
# .
# .
# .
# .
# #서울 #고양시 #고연전 #고려대 #연세대 #연고전 #2022 #럭비 #빙구 #아이스하키
# 졸업하기 전에 드디어 이겼다...😭
# 마지막이라 더욱 기억에 남을 고연전.
# .
# .
# .
# .
# .
# #고연전 #고연전🐯 #농구
# 자 지축을 박차고 포효하라 그대.
# 처음에는 무서웠는데 너무 재미있는 응원이었어요.
# 힘내라 고려대학교!
# #신이안 #202210 #고연전 #고려대 #koreauniversity
# 제대로 처음 즐겨본 #고연전
# 압승이용 ~ ㅋ ㅋ 연대 바보 ! 🐤
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 나도 봤다 러버덕(•́ɞ•̀)
# 고대 압승♥️🎉
# #고연전#즐거운고연전날에연대생우는소리
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 좋아하는 사람들 덕분에 최고로 행복했던
# #고연전 recap❤️
# 첫 고연전🐯❣️
# 🐯✌️
# #고연전 #연고전
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# #연고전 #고연전
# 여러분에게 따뜻한 공간이 되길 바랍니다.
# 오늘도 오앤오는 12시까지 열려있어요 🫒🍊
# ⠀⠀⠀
# ⠀⠀⠀⠀
# 🔻 매일 새로운 짤&정보 얻고싶다면 🔻
# ______________________________
# @ruby_ssame @ruby_ssame
# @ruby_ssame @ruby_ssame
# ______________________________
# ⠀⠀
# ⠀⠀⠀
# #웃짤 #짤방 #짤모음 #웃긴영상
# #선팔하면맞팔 #좋반 #좋테반사
# ⠀⠀
# ⠀⠀⠀
# 늦어도 답방가요 ·̑◡·̑
# ⠀
# 문제시 DM주세요 🙏🏻
# ⠀⠀⠀⠀⠀
# 즐거운 고연전 날에🎶
# #고려대 #고연전 #압승
# Go-Yeon Jeon’dan son fotoğraflar🐯
# Last photos from Go-Yeon Jeon🐯
# 이제 기억도 안 나는 그 정기전.. ㅋ
# ⠀
# 10월 중순부터 사진이 쌓이고 쌓여 있는데 손 댈 엄두가 안 난다. 원래도 애들이랑 같이 간 거라 사진 못 찍을 거 같아 카메라 없이 보는 정기전이 어쩌고 저쩌고 하다 좀 여유가 생겨 가져간 카메라를 꺼냈지?
# ⠀
# 1피 끝나고 누군지 모르는 사람이 허가 받지 않은 사람은 데세랄로 사진 찍으면 퇴장이라고 엄포를 놓길래 2피부턴 사진 못 찍음. ^^
# ⠀
# 그래도 뭐, 내 고딩 원픽이었던 자의 대학 4학년 정기전 세리머니 찍었으니 됐지 뭐. 민완이만 자르고 싶어도 뒤에 민재가 너무나도 강렬하여... ㅋ
# ⠀
# 민재 인스타 아이디 아는 사람? 태그를 못 걸겠네.
# ⠀
# #아이스하키 #정기전 #고연전 #연고전 #89 #내옛날고교원픽 #icehockey #hockey #hockeyplayer #アイスホッケー#현실도피중 @kangminwan89
# 내 사람들과 함께 웃을 수 있다는 것에 감사하며, 나의 첫 고연전 끝!
# 내년에도 허리 끊어지게 놀아야해~😁
# #고연전
# 고대천재🐯 연대바보🦅
# #고연전
#
#
#
#
#
#
# ################################3페이지##########################################################################
#
#
#
# 첫 고연전 성공❤️‍🔥
# #고연전 #연고전 #고려대 #연세대
# 내가 사랑하는 고대❤️
# 내가 사랑하는 통계❤️
# 애니멀 사운드 발사!!!🐯🐯🐯
# .
# .
# .
# .
# #고연전 #연고전 #아닙니다
# #고려대학교 #사랑해
# 연고전? k k  rghb
# #연고전 #고연전
# 평화를 가져다 주렴🙏
# #석촌호수 #러버덕 #사랑 #평화 #사진 #친구 #합격 #고려대 #고연전 #연고전 #축하 #코디 #ma1 #패션
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# 𝒀𝑶𝑼𝑵𝑮 𝑻𝑰𝑮𝑬𝑹𝑺
# #고연전 #필승전승압승🐯
# #2022정기고연전 #농구
# 20221028 / 고양체육관
# #정기고연전 #정기연고전
# #고연전 #연고전
# #고려대학교응원단 #고려대학교
# #고려대학교농구부
# #잠실야구장
# #디카츄_고려대학교응원단
# #디카츄_마음의고향
# #디카츄_Sports
# #디카츄의사진창고 #디카츄
# 친구 따라 강남 가듯 친구 따라 고연전
# #고연전 #연고전 #daily #dailylook #대전 #인천 #98 #응원 #응원단 #ootd #데일리룩 #소통해요 #좋반 #좋아요그램 #일상 #오오티디 #선팔하면맞팔 #팔로미🙋 #フォローバック #いいねした人全員ファローする #응원전 #🐯 #🦅#고려대 #연세대 #민족의아리아 #연세여사랑한다
# SPARTAN-LADY ICEHOCKEY TEAM
# 수요일 21:00-22:30
# 토요일 20:30-22:00
# 11월 5일, 12일 체험 자리 남았습니다~!
# - 정식 팀원 모집중💜
# - 체험 문의는 상단 링크 클릭👆🏻😀
# spartanicehockey_lady
# #스포츠
# #운동하는여자
# #하키
# #하키맘
# #하키스타그램
# #하키선수
# #아이스하키
# #고려대학교
# #아이스하키레슨
# #하키레슨
# #하키꿈나무
# #운동하는여자
# #여자운동
# #고연전
# #하남아이스박스
# #연고전
# #원데이클라스
# #빙구
# #정기전
# 연세대 : 고려대 3년만의 정기전
# 22/10/28
# 진정한 라이벌 게임.
# 어디서도 느껴보지 못한 응원전의 열기는
# 정말 잊을수 없는 경험이자 추억이 되었다.
# (Feat : 형들과 함께한 잊지못할 게임)
# It’s the most important rival game in Korea.
# The heat of the fan chant that I've never felt anywhere else.
# It became an unforgettable experience and memory. (with Brotherhood)
# #연고전2022 #연고전 #고연전 #정기전 #Chase.GipiJung.Jason #brotherhood #referee #refereelife #농구심판 #basketball #latepost #221028
# 🐅🐓 #고연전 #고려대학교 #19학번
# 첫 #고연전 ❤️
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# 한 번 뿐인 내 23살
# 2022 연고전
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# #연고전 #2022연고전 #고연전
# #첫줄
# 몇 년만에 #고연전 인가...!
# #야구 패 #아이스하키 승 #농구 승 #럭비 승 #축구 패
# 3:2로 고려대 #이겼다또이겼다
# #데이트 #럽스타그램 #❤️ #고려대 #고려대학교 #고려대학교세종캠퍼스 #민족고대 #고양
# #2022고연전 #기록
# 결혼한지 3년이되서야 성철이랑 처음으로 같이 간 고연전(2019년 태풍으로 취소, 그 이후는 코로나)
# 32살이나 먹었는데도 고연전은 여전히 어딘가 벅차고 뭉클한 뭔가가 있다🥲🥲
# 이번에도 응원곡을 부르고 올 줄은 몰랐는데.. 기연이의 부탁덕분에 매번 강제로 부르던 청춘예찬이 아닌 들보기를 불렀다🤣🤣
# 맨날 응원곡을 부르던 시절만큼의 느낌은 안나긴 하지만 그래도 역시 응원곡부르면 여전히 너무 신남😍🥰
# (마이크잡았더니 우루루 뛰어와선 단상앞에 옹기종기모여서 귀엽게 앉아서 보는ㅠ보컬애기들사진이 없어서 아쉽ㅋㅋㅋㅋㅋ)
# #들어라보아라그리고기억하라
# #들보기
# #고연전
# #고대응원단
# #고대응원곡
# #고연전 ,
# 2022.10.29.
# 3년만에 열린 고연전
# 3:2 고대 승☺️
# .
# .
# .
# .
# #고.전 #연고전 #고연전 #고려대 #야구 #잠실야구장 #취미사진 #리코gr3 #응원단 #가을
# 2022 정기 고연전 단체사진 ❤️❤️
# 집에 가지마! 안암으로 와! 신촌은 골로골로 골로골로 골로 간다~~
# P.S. 같이 사진 찍어주신 분들 다 사랑합니다 ❤️❤️
# 고연전🐯
# .
# 고대가 이겼으니까 “연고전 아님?” 이런 댓글 ㄴㄴ~
# .
# .
# #고연전 #연고전 #고대 #연대 #정기전 #응원 #19 #아직안고인물
# 짝꿍이랑 둘이 #쌀국수 #분짜 #모닝글로리볶음 #코코넛라떼 #고연전
# 추억82
# 이번에 고연전 우승했더라?
# #고려대 #연세대 #고연전 #정기고연전 #정기전 #고려대학교축구부 #고려대축구부 #고대 #고대축구부 #트레이너 #선수트레이너 #재활트레이너 #의무트레이너 #추억팔이 #추억82 #추억 #축구 #축구부 #축구팀 #우승 #승리 #koreauniversity #안암호랑이 #안암 #고려대학교체육위원회 #녹지운동장
# 즐거운 고연전 날에 연대생 우는 소리 아주 잘 들었습니다 🐯 #고연전
# 2022 연고전
# 재밌었습니다~~
# #연고전 #고연전 #연세대
# 자 지축을 박차고~ 자 포효하라 그대~
# #고연전 #고양종합운동장
# 2022 정기 고연전 🏈⚽️
# "우리의 함성은 신화가 되리라"
# .
# #고연전 #연고전 #럭비 #축구 #고려대학교 #연세대학교 #고려대 #연세대 #정기전 #신촌독수리 #안암호랑이 #🐅🦅 #고양종합운동장 #포에버 #민족의아리아 #우리의함성은신화가되리라 #20221029
# #고연전 1일차
# 오랜만에 간 춘자가 너무 재밌었다
# 내 장점이 뭔지 알아-?바로 새내긴거양~👼
# Day1 221031
# .
# 플래너 사서 27일부터 시작했지만 어림없지
# 고연전 열심히 즐기고 다시 오늘부터 시작
# 첫 고연전 끄읕 ❤️‍🔥
# #고연전 #고려대
# 뱃노래🔂
# #고연전
# 히히 즐거운 고연전
# #고연전 #고연전🐯 #필승전승압승 #즐거운고연전날에연대생우는소리 #고려대
