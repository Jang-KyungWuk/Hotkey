# %%
from requests import get, post, Session
from urllib import parse
import json
from datetime import datetime
import pickle as pkl
from konlpy.tag import Okt
okt = Okt()

# %%
with open('../../recent_list.pkl', 'rb') as f:
    b = pkl.load(f)

# %%
oktnounlist=list()
for i in b:
    oktnounlist=oktnounlist+okt.nouns(i)

# %%
oktnounlist
# Out:
# ['오늘',
#  '지각',
#  '벌점',
#  '내일',
#  '일찍',
#  '사회',
#  '발',
#  '응원',
#  '발',
#  '모든',
#  '분',
#  '응원',
#  '모',
#  '두',
#  '힘',
#  '내',
#  '이벤트',
#  '참여',
#  '방법',
#  '보건복지부',
#  '인스타그램',
#  '채널',
#  '팔로우',
#  '기존',
#  '팔로워',
#  '소문내기',
#  '친구',
#  '태그',
#  '응원',
#  '댓글',
#  '태그',
#  '친구',
#  '팔로우',
#  '당첨',
#  '확률',
#  '팔로우',
#  '도',
#  '수록',
#  '당첨',
#  '확률',
#  '이벤트',
#  '경품',
#  '굽네치킨',
#  '고추',
#  '콜라',
#  '명',
#  '이벤트',
#  '기간',
#  '당첨',
#  '발표',
#  '인스타그램',
#  '피드',
#  '통해',
#  '발표',
#  '수능',
#  '영어',
#  '리스닝',
#  '풀',
#  '레벨',
#  '아이',
#  '리틀',
#  '팍스',
#  '리스닝',
#  '비',
#  '수능',
#  '영어',
#  '리스닝',
#  '속도',
#  '평',
#  '평',
#  '해설',
#  '강의',
#  '수능',
#  '해설',
#  '강의',
#  '언제',
#  '심바',
#  '여기',
#  '여기',
#  '화요일',
#  '이투스',
#  '선생님',
#  '수능',
#  '해설',
#  '강의',
#  '업로드',
#  '킬러',
#  '지문',
#  '과학',
#  '지문',
#  '독해',
#  '방법',
#  '선생님',
#  '글',
#  '내일',
#  '이투스',
#  '수험생',
#  '여러분',
#  '모두',
#  '박',
#  '수험생',
#  '수능',
#  '탈출',
#  '축하',
#  '이벤트',
#  '이제',
#  '랜드',
#  '인스타그램',
#  '랜드',
#  '친구',
#  '소환',
#  '서울',
#  '랜드',
#  '초대권',
#  '기간',
#  '목',
#  '화',
#  '싱픔',
#  '서울',
#  '랜드',
#  '초대권',
#  '매',
#  '명',
#  '참여',
#  '방법',
#  '친구',
#  '소환',
#  '서울',
#  '랜드',
#  '이벤트',
#  '게시',
#  '물',
#  '리그',
#  '램',
#  '캡쳐',
#  '업로드',
#  '해시태그',
#  '필수',
#  '계정',
#  '팔로우',
#  '당첨',
#  '확률',
#  '당첨',
#  '발표',
#  '이후',
#  '개별',
#  '발송',
#  '제공',
#  '초대권',
#  '비매품',
#  '양도',
#  '및',
#  '판매',
#  '수능',
#  '동생',
#  '출처',
#  '다음',
#  '카페',
#  '밀리',
#  '토리',
#  '제보',
#  '학년',
#  '입시',
#  '마무리',
#  '및',
#  '학년',
#  '준비',
#  '관',
#  '피드입니',
#  '제',
#  '입시',
#  '과정',
#  '주관',
#  '멘트',
#  '다소',
#  '보기',
#  '수',
#  '피드',
#  '분',
#  '시일',
#  '내',
#  '공부',
#  '게시',
#  '물',
#  '글',
#  '분',
#  '감사',
#  '디자인',
#  '탈색',
#  '염색',
#  '탈색',
#  '고객',
#  '얼마',
#  '전',
#  '검정',
#  '규',
#  '당장',
#  '오늘',
#  '해',
#  '규',
#  '그대',
#  '살롱드미',
#  '추천',
#  '구미',
#  '옥계',
#  '살롱',
#  '드',
#  '문의',
#  '주시',
#  '감사',
#  '월화',
#  '당신',
#  '위해',
#  '예약',
#  '구미시',
#  '산호',
#  '길',
#  '너',
#  '퐁실퐁실',
#  '토토',
#  '인스',
#  '역시',
#  '무채색',
#  '인스',
#  '얼른',
#  '회색',
#  '하트',
#  '이모지',
#  '빼빼로데이',
#  '구나',
#  '피드',
#  '저',
#  '때',
#  '빼빼로',
#  '이제',
#  '이벤트',
#  '데이',
#  '안',
#  '오늘',
#  '수능',
#  '다시',
#  '등교',
#  '짱',
#  '피곤',
#  '제',
#  '자리',
#  '수능',
#  '보신',
#  '웅',
#  '저',
#  '선택',
#  '과목',
#  '기',
#  '짝수',
#  '제외',
#  '짝수',
#  '제외',
#  '학년',
#  '대수능',
#  '번',
#  '난이도',
#  '평',
#  '발상',
#  '계산',
#  '대표',
#  '그림',
#  '하나',
#  '평행선',
#  '개',
#  '요리조리',
#  '극한',
#  '난',
#  '계산',
#  '수험생',
#  '모두',
#  '정말',
#  '수고',
#  '이제',
#  '이번',
#  '주말',
#  '초',
#  '면접',
#  '일정',
#  '알',
#  '그',
#  '시리즈',
#  '준비',
#  '년',
#  '전의',
#  '차차',
#  '면접',
#  '한번',
#  '발표',
#  '목소리',
#  '적',
#  '고딩',
#  '시절',
#  '면접',
#  '사실',
#  '저',
#  '미스테리',
#  '만요',
#  '이번',
#  '주',
#  '내',
#  '성수고',
#  '고',
#  '학기',
#  '기말고사',
#  '기출',
#  '분석',
#  '기말고사',
#  '기출',
#  '분석',
#  '통한',
#  '국어',
#  '성적',
#  '향상',
#  '도움',
#  '자료',
#  '성수고',
#  '최',
#  '상위',
#  '학생',
#  '공부',
#  '수',
#  '중',
#  '하위',
#  '수',
#  '요소',
#  '문제',
#  '부분',
#  '때',
#  '국어',
#  '이론',
#  '또',
#  '다른',
#  '해',
#  '고전',
#  '시가',
#  '대시',
#  '중심',
#  '문항',
#  '주가',
#  '때',
#  '서술',
#  '객관',
#  '학교',
#  '특성',
#  '매',
#  '해',
#  '다른',
#  '성격',
#  '출제',
#  '경향',
#  '학교',
#  '선생님',
#  '말씀',
#  '더',
#  '더욱',
#  '학교',
#  '교차',
#  '커서',
#  '아침',
#  '저녁',
#  '내일',
#  '비',
#  '소식',
#  '국어',
#  '학습',
#  '학교',
#  '수험생',
#  '고',
#  '최',
#  '상위',
#  '공부',
#  '팁',
#  '기출',
#  '분석',
#  '시험',
#  '공략',
#  '국어',
#  '수능',
#  '정복',
#  '학습',
#  '기말고사',
#  '국어',
#  '시험',
#  '공부',
#  '법',
#  '생각',
#  '반사',
#  '바디',
#  '채널',
#  '주점',
#  '얼마',
#  '전',
#  '수능',
#  '시험',
#  '수험생',
#  '여러분',
#  '수능',
#  '고생',
#  '모든',
#  '수험생',
#  '결과',
#  '바디',
#  '채널',
#  '주점',
#  '수험생',
#  '할인',
#  '이벤트',
#  '준비',
#  '회원',
#  '개월',
#  '별도',
#  '별도',
#  '수험표',
#  '필수',
#  '바디',
#  '채널',
#  '운동',
#  '트렌디',
#  '클럽',
#  '인테리어',
#  '컨셉',
#  '연중',
#  '무',
#  '헬스',
#  '요가',
#  '필라테스',
#  '그룹',
#  '전',
#  '지점',
#  '프리',
#  '패스',
#  '이용',
#  '가능',
#  '방문',
#  '상담',
#  '제주시',
#  '서광',
#  '로',
#  '그랜드',
#  '타워',
#  '층',
#  '안내',
#  '데스크',
#  '문의',
#  '전화',
#  '생명',
#  '위',
#  '살구',
#  '위로',
#  '엽서',
#  '소개',
#  '살구',
#  '위로',
#  '엽서',
#  '지난',
#  '마무리',
#  '수능',
#  '관',
#  '글',
#  '긴장',
#  '아침',
#  '북적',
#  '교실',
#  '끝',
#  '시작',
#  '발걸음',
#  '여러분',
#  '시작',
#  '응원',
#  '살구',
#  '위로',
#  '엽서',
#  '글',
#  '하루',
#  '운동',
#  '맛집',
#  '인스타',
#  '성',
#  '화이트',
#  '톤',
#  '사진',
#  '맛집',
#  '얼른',
#  '오운완',
#  '인증샷',
#  '모',
#  '대전',
#  '프리미엄',
#  '헬스',
#  '조',
#  '청결',
#  '헬스장',
#  '여성',
#  '회원',
#  '추가',
#  '할인',
#  '스트레칭',
#  '존',
#  '존',
#  '공간',
#  '분리',
#  '주차',
#  '시설',
#  '바디',
#  '프로필',
#  '재활',
#  '교정',
#  '시합',
#  '필라테스',
#  '각',
#  '분야',
#  '전문',
#  '남여',
#  '트레이너',
#  '상주',
#  '개인',
#  '부스',
#  '샤워실',
#  '천국',
#  '계단',
#  '등',
#  '유',
#  '산소',
#  '운동',
#  '기구',
#  '보유',
#  '부티',
#  '몬스터',
#  '글',
#  '루트',
#  '등',
#  '힙',
#  '운동',
#  '기구',
#  '보유',
#  '실적',
#  '제',
#  '트레이너',
#  '문의',
#  '상담',
#  '카카오',
#  '조',
#  '멘토',
#  '점',
#  '목표',
#  '인증',
#  '미세먼지',
#  '로부터',
#  '공기',
#  '청정',
#  '멘토',
#  '점',
#  '공부',
#  '오늘',
#  '멘토',
#  '점',
#  '내신',
#  '성적',
#  '상승',
#  '수능',
#  '대박',
#  '자격증',
#  '시험',
#  '합격',
#  '취업',
#  '성공',
#  '모든',
#  '공부',
#  '공',
#  '열공',
#  '빡공',
#  '완공',
#  '토리',
#  '화이팅',
#  '츠',
#  '스낵',
#  '타임',
#  '수능',
#  '편',
#  '학년',
#  '이츠',
#  '응원',
#  '능력',
#  '시험',
#  '개최',
#  '쿠팡',
#  '츠',
#  '영역',
#  '풀',
#  '쿠폰',
#  '정답',
#  '모두',
#  '분',
#  '추첨',
#  '통해',
#  '식사',
#  '원금',
#  '참여',
#  '방법',
#  '쿠팡',
#  '츠',
#  '팔로우',
#  '댓글',
#  '정답',
#  '친구',
#  '태그',
#  '끝',
#  '이벤트',
#  '스토리',
#  '게시',
#  '글',
#  '리그',
#  '램',
#  '태그',
#  '당첨',
#  '확률',
#  '경품',
#  '안내',
#  '당첨',
#  '총',
#  '명',
#  '경품',
#  '쿠팡',
#  '츠',
#  '쿠폰',
#  '일정',
#  '참여',
#  '기간',
#  '당첨',
#  '발표',
#  '당첨',
#  '개별',
#  '이벤트',
#  '당사',
#  '사정',
#  '사전',
#  '예고',
#  '변경',
#  '취소',
#  '수',
#  '쿠팡',
#  '츠',
#  '인스타그램',
#  '팔로워',
#  '위',
#  '이벤트',
#  '앞',
#  '계속',
#  '더',
#  '식사',
#  '시작',
#  '쿠팡',
#  '츠',
#  '룩스',
#  '필라테스',
#  '사거리',
#  '점',
#  '지인',
#  '소개',
#  '이벤트',
#  '기존',
#  '회원',
#  '위',
#  '깜짝',
#  '이벤트',
#  '지인',
#  '상담',
#  '후',
#  '등록',
#  '경우',
#  '횟수',
#  '추가',
#  '최대',
#  '기간',
#  '연장',
#  '개월',
#  '필라',
#  '복',
#  '증정',
#  '혜택',
#  '주변',
#  '지인',
#  '분',
#  '룩스',
#  '필라테스',
#  '사거리',
#  '점',
#  '소문',
#  '상담',
#  '문의',
#  '전화',
#  '카톡',
#  '모든',
#  '상담',
#  '예약',
#  '제로',
#  '운영',
#  '미리',
#  '연락',
#  '주시',
#  '상담',
#  '도',
#  '삼양동',
#  '사거리',
#  '삼양동',
#  '사거리',
#  '룩스',
#  '필라테스',
#  '그룹',
#  '레슨',
#  '수험생',
#  '이벤트',
#  '앞',
#  '게시',
#  '대한',
#  '저번',
#  '의견',
#  '종합',
#  '첫',
#  '장',
#  '의견',
#  '가장',
#  '후보',
#  '개',
#  '두번째',
#  '장',
#  '내일',
#  '모레',
#  '게시',
#  '물',
#  '대한',
#  '공지',
#  '마지막',
#  '장',
#  '앞',
#  '하나',
#  '확정',
#  '게시',
#  '물',
#  '첫',
#  '장의',
#  '가지',
#  '후보',
#  '대해',
#  '가장',
#  '먼저',
#  '피드',
#  '댓글',
#  '게시',
#  '물',
#  '후보',
#  '모두',
#  '다만',
#  '그',
#  '순서',
#  '대해',
#  '의견',
#  '것',
#  '방식',
#  '대해',
#  '서도',
#  '말씀',
#  '다른',
#  '댓글',
#  '보시',
#  '자신',
#  '의견',
#  '를',
#  '번',
#  '예비',
#  '의',
#  '공부',
#  '량',
#  '공부',
#  '방향',
#  '피드',
#  '현',
#  '등급',
#  '대별',
#  '얘기',
#  '번',
#  '공부자',
#  '멘트',
#  '모음',
#  '피드',
#  '적',
#  '멘트',
#  '위주',
#  '디엠',
#  '개',
#  '이상',
#  '확인',
#  '중이',
#  '디엠',
#  '댓글',
#  '것',
#  '혹시',
#  '댓글',
#  '리지',
#  '분',
#  '최근',
#  '팔로우',
#  '경우',
#  '나',
#  '팔로우',
#  '경우',
#  '일',
#  '혹시',
#  '이',
#  '경우',
#  '댓글',
#  '디엠',
#  '말씀',
#  '단',
#  '확인',
#  '수',
#  '의견',
#  '수렴',
#  '기간',
#  '수요일',
#  '참여',
#  '오늘',
#  '어원',
#  '대해',
#  '주변',
#  '의미',
#  '가지',
#  '옆',
#  '를',
#  '여러분',
#  '알',
#  '단어',
#  '중',
#  '주변',
#  '로',
#  '시작',
#  '단어',
#  '무엇',
#  '아시',
#  '분',
#  '댓글',
#  '어휘',
#  '공부',
#  '꿀팁',
#  '장소',
#  '를',
#  '클릭',
#  '더',
#  '자료',
#  '콘텐츠',
#  '꼭',
#  '를',
#  '팔로우',
#  '암기',
#  '어원',
#  '어휘',
#  '주변',
#  '왕초보',
#  '탈출',
#  '내신',
#  '토익',
#  '토플',
#  '텝스',
#  '멘토링',
#  '수능',
#  '입시',
#  '공시',
#  '편입',
#  '자기계발',
#  '멘탈',
#  '관리',
#  '동기부여',
#  '습관',
#  '루틴',
#  '스타',
#  '그램',
#  '예비',
#  '초',
#  '우리나라',
#  '스터디',
#  '반',
#  '벌써',
#  '줌',
#  '수업',
#  '진행중',
#  '월요일',
#  '저녁',
#  '총',
#  '비대',
#  '전국',
#  '수업',
#  '세',
#  '초등',
#  '학년',
#  '최고',
#  '준비',
#  '비대',
#  '수업',
#  '계',
#  '독서',
#  '권',
#  '액기스',
#  '수업',
#  '시간',
#  '매번',
#  '수업',
#  '학습',
#  '어휘',
#  '정리',
#  '수업',
#  '후기',
#  '덕',
#  '힘',
#  '반드시',
#  '진가',
#  '회원',
#  '기분',
#  '예감',
#  '인친',
#  '교원',
#  '계',
#  '독서',
#  '이제',
#  '시작',
#  '더',
#  '교원',
#  '교육',
#  '학습',
#  '프로그램',
#  '가입',
#  '활용',
#  '교원',
#  '교육',
#  '발도',
#  '젠',
#  '푸욱',
#  '돠',
#  '학년',
#  '대학',
#  '수학',
#  '능력',
#  '시험',
#  '풀이',
#  '과정',
#  '학년',
#  '수능',
#  '끝',
#  '리',
#  '유입',
#  '니',
#  '학년',
#  '대학',
#  '수학',
#  '능력',
#  '치',
#  '루신',
#  '모든',
#  '수험생',
#  '여러분',
#  '정말',
#  '수고',
#  '노력',
#  '보상',
#  '당장',
#  '보이지',
#  '젠',
#  '길로',
#  '은',
#  '저',
#  '수험표',
#  '고생',
#  '수험생',
#  '음료수',
#  '차슈',
#  '간장',
#  '계란',
#  '구성',
#  '서비스',
#  '해',
#  '모두',
#  '하리보',
#  '학년',
#  '수능',
#  '공통',
#  '수학',
#  '코멘트',
#  '나중',
#  '바디',
#  '채널',
#  '남녕',
#  '점',
#  '얼마',
#  '전',
#  '수능',
#  '시험',
#  ...]

# %%
voca = dict()
for term in oktnounlist:
    if term in voca:
        voca[term] += 1
    else:
        voca[term] = 1

# %%
voca
# Out:
# {'오늘': 48,
#  '지각': 1,
#  '벌점': 1,
#  '내일': 11,
#  '일찍': 2,
#  '사회': 11,
#  '발': 9,
#  '응원': 69,
#  '모든': 71,
#  '분': 86,
#  '모': 6,
#  '두': 5,
#  '힘': 2,
#  '내': 32,
#  '이벤트': 362,
#  '참여': 59,
#  '방법': 33,
#  '보건복지부': 1,
#  '인스타그램': 35,
#  '채널': 31,
#  '팔로우': 38,
#  '기존': 8,
#  '팔로워': 9,
#  '소문내기': 1,
#  '친구': 45,
#  '태그': 28,
#  '댓글': 47,
#  '당첨': 69,
#  '확률': 29,
#  '도': 30,
#  '수록': 2,
#  '경품': 29,
#  '굽네치킨': 1,
#  '고추': 1,
#  '콜라': 1,
#  '명': 53,
#  '기간': 68,
#  '발표': 40,
#  '피드': 8,
#  '통해': 36,
#  '수능': 349,
#  '영어': 17,
#  '리스닝': 3,
#  '풀': 19,
#  '레벨': 1,
#  '아이': 24,
#  '리틀': 1,
#  '팍스': 1,
#  '비': 14,
#  '속도': 1,
#  '평': 12,
#  '해설': 5,
#  '강의': 10,
#  '언제': 11,
#  '심바': 1,
#  '여기': 9,
#  '화요일': 2,
#  '이투스': 2,
#  '선생님': 10,
#  '업로드': 6,
#  '킬러': 1,
#  '지문': 32,
#  '과학': 4,
#  '독해': 5,
#  '글': 27,
#  '수험생': 409,
#  '여러분': 175,
#  '모두': 76,
#  '박': 1,
#  '탈출': 2,
#  '축하': 4,
#  '이제': 53,
#  '랜드': 6,
#  '소환': 5,
#  '서울': 21,
#  '초대권': 3,
#  '목': 17,
#  '화': 16,
#  '싱픔': 1,
#  '매': 4,
#  '게시': 32,
#  '물': 22,
#  '리그': 19,
#  '램': 19,
#  '캡쳐': 1,
#  '해시태그': 2,
#  '필수': 32,
#  '계정': 24,
#  '이후': 6,
#  '개별': 16,
#  '발송': 3,
#  '제공': 26,
#  '비매품': 1,
#  '양도': 1,
#  '및': 71,
#  '판매': 3,
#  '동생': 2,
#  '출처': 6,
#  '다음': 10,
#  '카페': 17,
#  '밀리': 1,
#  '토리': 4,
#  '제보': 1,
#  '학년': 53,
#  '입시': 17,
#  '마무리': 8,
#  '준비': 127,
#  '관': 14,
#  '피드입니': 1,
#  '제': 26,
#  '과정': 5,
#  '주관': 2,
#  '멘트': 3,
#  '다소': 3,
#  '보기': 7,
#  '수': 130,
#  '시일': 1,
#  '공부': 75,
#  '감사': 9,
#  '디자인': 15,
#  '탈색': 27,
#  '염색': 30,
#  '고객': 33,
#  '얼마': 5,
#  '전': 38,
#  '검정': 3,
#  '규': 2,
#  '당장': 23,
#  '해': 17,
#  '그대': 1,
#  '살롱드미': 1,
#  '추천': 28,
#  '구미': 4,
#  '옥계': 1,
#  '살롱': 4,
#  '드': 3,
#  '문의': 163,
#  '주시': 12,
#  '월화': 1,
#  '당신': 5,
#  '위해': 108,
#  '예약': 55,
#  '구미시': 1,
#  '산호': 1,
#  '길': 15,
#  '너': 11,
#  '퐁실퐁실': 1,
#  '토토': 1,
#  '인스': 2,
#  '역시': 2,
#  '무채색': 1,
#  '얼른': 2,
#  '회색': 1,
#  '하트': 3,
#  '이모지': 1,
#  '빼빼로데이': 2,
#  '구나': 1,
#  '저': 23,
#  '때': 33,
#  '빼빼로': 1,
#  '데이': 7,
#  '안': 7,
#  '다시': 11,
#  '등교': 1,
#  '짱': 1,
#  '피곤': 1,
#  '자리': 3,
#  '보신': 4,
#  '웅': 1,
#  '선택': 9,
#  '과목': 14,
#  '기': 6,
#  '짝수': 2,
#  '제외': 27,
#  '대수능': 2,
#  '번': 28,
#  '난이도': 12,
#  '발상': 1,
#  '계산': 2,
#  '대표': 5,
#  '그림': 4,
#  '하나': 12,
#  '평행선': 1,
#  '개': 16,
#  '요리조리': 1,
#  '극한': 1,
#  '난': 2,
#  '정말': 18,
#  '수고': 72,
#  '이번': 28,
#  '주말': 8,
#  '초': 7,
#  '면접': 14,
#  '일정': 12,
#  '알': 17,
#  '그': 21,
#  '시리즈': 2,
#  '년': 2,
#  '전의': 1,
#  '차차': 1,
#  '한번': 16,
#  '목소리': 1,
#  '적': 4,
#  '고딩': 3,
#  '시절': 1,
#  '사실': 2,
#  '미스테리': 1,
#  '만요': 1,
#  '주': 12,
#  '성수고': 2,
#  '고': 62,
#  '학기': 6,
#  '기말고사': 17,
#  '기출': 10,
#  '분석': 18,
#  '통한': 5,
#  '국어': 31,
#  '성적': 14,
#  '향상': 6,
#  '도움': 11,
#  '자료': 7,
#  '최': 8,
#  '상위': 5,
#  '학생': 34,
#  '중': 39,
#  '하위': 1,
#  '요소': 1,
#  '문제': 22,
#  '부분': 19,
#  '이론': 1,
#  '또': 9,
#  '다른': 13,
#  '고전': 1,
#  '시가': 1,
#  '대시': 2,
#  '중심': 1,
#  '문항': 10,
#  '주가': 1,
#  '서술': 2,
#  '객관': 2,
#  '학교': 17,
#  '특성': 3,
#  '성격': 1,
#  '출제': 10,
#  '경향': 5,
#  '말씀': 7,
#  '더': 69,
#  '더욱': 10,
#  '교차': 4,
#  '커서': 4,
#  '아침': 8,
#  '저녁': 10,
#  '소식': 10,
#  '학습': 14,
#  '팁': 5,
#  '시험': 63,
#  '공략': 3,
#  '정복': 3,
#  '법': 16,
#  '생각': 30,
#  '반사': 5,
#  '바디': 53,
#  '주점': 3,
#  '고생': 142,
#  '결과': 46,
#  '할인': 250,
#  '회원': 48,
#  '개월': 69,
#  '별도': 11,
#  '수험표': 105,
#  '운동': 61,
#  '트렌디': 2,
#  '클럽': 9,
#  '인테리어': 5,
#  '컨셉': 2,
#  '연중': 11,
#  '무': 15,
#  '헬스': 51,
#  '요가': 9,
#  '필라테스': 119,
#  '그룹': 31,
#  '지점': 3,
#  '프리': 3,
#  '패스': 3,
#  '이용': 21,
#  '가능': 57,
#  '방문': 58,
#  '상담': 92,
#  '제주시': 2,
#  '서광': 1,
#  '로': 29,
#  '그랜드': 1,
#  '타워': 5,
#  '층': 53,
#  '안내': 16,
#  '데스크': 5,
#  '전화': 55,
#  '생명': 3,
#  '위': 86,
#  '살구': 6,
#  '위로': 9,
#  '엽서': 6,
#  '소개': 10,
#  '지난': 17,
#  '긴장': 6,
#  '북적': 2,
#  '교실': 2,
#  '끝': 50,
#  '시작': 55,
#  '발걸음': 2,
#  '하루': 12,
#  '맛집': 19,
#  '인스타': 18,
#  '성': 1,
#  '화이트': 2,
#  '톤': 6,
#  '사진': 19,
#  '오운완': 3,
#  '인증샷': 3,
#  '대전': 18,
#  '프리미엄': 10,
#  '조': 2,
#  '청결': 1,
#  '헬스장': 22,
#  '여성': 2,
#  '추가': 65,
#  '스트레칭': 2,
#  '존': 7,
#  '공간': 5,
#  '분리': 2,
#  '주차': 17,
#  '시설': 17,
#  '프로필': 59,
#  '재활': 7,
#  '교정': 19,
#  '시합': 3,
#  '각': 7,
#  '분야': 8,
#  '전문': 27,
#  '남여': 1,
#  '트레이너': 12,
#  '상주': 1,
#  '개인': 42,
#  '부스': 4,
#  '샤워실': 2,
#  '천국': 12,
#  '계단': 4,
#  '등': 31,
#  '유': 9,
#  '산소': 3,
#  '기구': 32,
#  '보유': 27,
#  '부티': 1,
#  '몬스터': 1,
#  '루트': 1,
#  '힙': 1,
#  '실적': 1,
#  '카카오': 48,
#  '멘토': 6,
#  '점': 161,
#  '목표': 10,
#  '인증': 10,
#  '미세먼지': 1,
#  '로부터': 1,
#  '공기': 1,
#  '청정': 1,
#  '내신': 6,
#  '상승': 2,
#  '대박': 6,
#  '자격증': 5,
#  '합격': 13,
#  '취업': 9,
#  '성공': 5,
#  '공': 5,
#  '열공': 4,
#  '빡공': 2,
#  '완공': 2,
#  '화이팅': 8,
#  '츠': 47,
#  '스낵': 7,
#  '타임': 11,
#  '편': 14,
#  '이츠': 8,
#  '능력': 35,
#  '개최': 10,
#  '쿠팡': 40,
#  '영역': 21,
#  '쿠폰': 30,
#  '정답': 26,
#  '추첨': 22,
#  '식사': 18,
#  '원금': 8,
#  '스토리': 11,
#  '총': 13,
#  '당사': 8,
#  '사정': 10,
#  '사전': 12,
#  '예고': 8,
#  '변경': 20,
#  '취소': 12,
#  '앞': 43,
#  '계속': 11,
#  '룩스': 3,
#  '사거리': 4,
#  '지인': 5,
#  '깜짝': 4,
#  '후': 47,
#  '등록': 43,
#  '경우': 18,
#  '횟수': 8,
#  '최대': 50,
#  '연장': 9,
#  '필라': 3,
#  '복': 2,
#  '증정': 27,
#  '혜택': 97,
#  '주변': 6,
#  '소문': 1,
#  '카톡': 31,
#  '제로': 3,
#  '운영': 27,
#  '미리': 8,
#  '연락': 18,
#  '삼양동': 2,
#  '레슨': 48,
#  '대한': 14,
#  '저번': 1,
#  '의견': 5,
#  '종합': 3,
#  '첫': 21,
#  '장': 6,
#  '가장': 17,
#  '후보': 3,
#  '두번째': 10,
#  '모레': 2,
#  '공지': 2,
#  '마지막': 11,
#  '확정': 2,
#  '장의': 6,
#  '가지': 22,
#  '대해': 14,
#  '먼저': 5,
#  '다만': 1,
#  '순서': 3,
#  '것': 54,
#  '방식': 1,
#  '서도': 1,
#  '보시': 5,
#  '자신': 10,
#  '를': 14,
#  '예비': 7,
#  '의': 17,
#  '량': 2,
#  '방향': 1,
#  '현': 3,
#  '등급': 5,
#  '대별': 2,
#  '얘기': 1,
#  '공부자': 1,
#  '모음': 4,
#  '위주': 1,
#  '디엠': 17,
#  '이상': 32,
#  '확인': 34,
#  '중이': 4,
#  '혹시': 3,
#  '리지': 4,
#  '최근': 3,
#  '나': 33,
#  '일': 27,
#  '이': 42,
#  '단': 15,
#  '수렴': 1,
#  '수요일': 1,
#  '어원': 2,
#  '의미': 10,
#  '옆': 6,
#  '단어': 11,
#  '무엇': 4,
#  '아시': 2,
#  '어휘': 10,
#  '꿀팁': 3,
#  '장소': 7,
#  '클릭': 13,
#  '콘텐츠': 2,
#  '꼭': 41,
#  '암기': 2,
#  '왕초보': 1,
#  '토익': 5,
#  '토플': 1,
#  '텝스': 2,
#  '멘토링': 1,
#  '공시': 1,
#  '편입': 1,
#  '자기계발': 1,
#  '멘탈': 1,
#  '관리': 26,
#  '동기부여': 4,
#  '습관': 3,
#  '루틴': 2,
#  '스타': 19,
#  '그램': 19,
#  '우리나라': 1,
#  '스터디': 11,
#  '반': 4,
#  '벌써': 3,
#  '줌': 1,
#  '수업': 34,
#  '진행중': 18,
#  '월요일': 7,
#  '비대': 2,
#  '전국': 8,
#  '세': 6,
#  '초등': 4,
#  '최고': 24,
#  '계': 7,
#  '독서': 15,
#  '권': 3,
#  '액기스': 1,
#  '시간': 57,
#  '매번': 4,
#  '정리': 7,
#  '후기': 11,
#  '덕': 1,
#  '반드시': 1,
#  '진가': 1,
#  '기분': 7,
#  '예감': 1,
#  '인친': 1,
#  '교원': 3,
#  '교육': 12,
#  '프로그램': 7,
#  '가입': 12,
#  '활용': 3,
#  '발도': 1,
#  '젠': 3,
#  '푸욱': 1,
#  '돠': 1,
#  '대학': 42,
#  '수학': 32,
#  '풀이': 2,
#  '리': 7,
#  '유입': 1,
#  '니': 5,
#  '치': 5,
#  '루신': 1,
#  '노력': 28,
#  '보상': 3,
#  '보이지': 3,
#  '길로': 1,
#  '은': 9,
#  '음료수': 1,
#  '차슈': 1,
#  '간장': 1,
#  '계란': 1,
#  '구성': 5,
#  '서비스': 32,
#  '하리보': 1,
#  '공통': 1,
#  '코멘트': 3,
#  '나중': 2,
#  '남녕': 2,
#  '부가세': 4,
#  '도령로': 1,
#  '봉금': 1,
#  '빌딩': 10,
#  '블리상점': 1,
#  '대구': 12,
#  '도토리': 2,
#  '상점': 2,
#  '입점': 1,
#  '로데오': 1,
#  '거리': 5,
#  '이름': 4,
#  '가세': 1,
#  '지금': 48,
#  '귀걸이': 2,
#  '가격': 28,
#  '키링': 7,
#  '화학': 1,
#  '예상': 5,
#  '컷': 22,
#  '묘연': 1,
#  '가족': 46,
#  '상의': 3,
#  '입양': 1,
#  '오픈': 20,
#  '톡': 34,
#  '타로': 3,
#  '소': 1,
#  '분한': 1,
#  '타로점': 2,
#  '쏙쏙': 1,
#  '환영': 14,
#  '링크': 39,
#  '타고': 2,
#  '스프링보드': 2,
#  '복부': 4,
#  '효과': 10,
#  '굿': 5,
#  '시퀀스': 1,
#  '자세': 7,
#  '테이블': 1,
#  '탑': 5,
#  '양': 2,
#  '손': 5,
#  '머리': 44,
#  '만세': 1,
#  '롤': 2,
#  '다운': 12,
#  '바': 5,
#  '발가락': 1,
#  '지지': 1,
#  '요': 16,
#  '진행': 75,
#  '동작': 1,
#  '다리': 6,
#  '자': 7,
#  '유지': 4,
#  '말': 20,
#  '동시': 9,
#  '사이': 2,
#  '쏙': 1,
#  '팔': 1,
#  '미사': 3,
#  '강변': 2,
#  '힐스테이트': 2,
#  '에코': 3,
#  '호': 9,
#  '속눈썹': 20,
#  '펌': 25,
#  '셀카': 1,
#  '귀염뽀짝': 1,
#  '세트': 4,
#  '구매': 49,
#  '영양': 7,
#  '꼭꼭': 1,
#  '케어': 8,
#  '길이': 7,
#  '두께': 1,
#  '잡': 1,
#  '플레인': 3,
#  '브로': 2,
#  '검색': 19,
#  '옆피드': 1,
#  '릴스': 1,
#  '비포': 1,
#  '애프터': 1,
#  '보장': 3,
#  '수가': 1,
#  '눈매': 4,
#  '파악': 4,
#  '롯드': 1,
#  '제대로': 10,
#  '시술': 71,
#  '문': 2,
#  '피어싱': 3,
#  '대한민국': 10,
#  '술시': 6,
#  '바벨': 1,
#  '볼': 5,
#  '컬': 4,
#  '사용': 36,
#  '알러지': 2,
#  '제품': 7,
#  '테리어': 1,
#  '위치': 9,
#  '고민': 20,
#  '귀': 1,
#  '상태': 5,
#  '요청': 1,
#  '매장': 19,
#  '손님': 2,
#  '응': 1,
#  '답변': 8,
#  '최대한': 3,
#  '그동안': 51,
#  '산': 19,
#  '우리': 76,
#  '저희': 44,
#  '동반': 35,
#  '인': 35,
#  '헤어': 42,
#  '동탄': 91,
#  '솔빛': 17,
#  '나루': 30,
#  '미용실': 29,
#  '여자': 19,
#  '남자': 25,
#  '탄솔': 15,
#  '빛': 19,
#  '연두': 1,
#  '줄': 6,
#  '바꿈': 1,
#  '뜻': 4,
#  '게': 10,
#  '장기': 2,
#  '예문': 3,
#  '식': 3,
#  '문장': 2,
#  '해석': 6,
#  '이해': 3,
#  '일상': 3,
#  '평소': 2,
#  '맥락': 1,
#  '때문': 8,
#  '칠': 3,
#  '분명': 3,
#  '표현': 1,
#  '보고': 16,
#  '공유': 3,
#  '피드백': 2,
#  '한국사': 7,
#  '세계사': 2,
#  '동아시아사': 2,
#  '블로그': 5,
#  '완료': 10,
#  '무난': 2,
#  '함': 3,
#  '극악': 1,
#  '몇몇': 1,
#  '못': 7,
#  '정도': 5,
#  '보통': 2,
#  '약간': 2,
#  '듯': 5,
#  '나머지': 1,
#  '대체로': 1,
#  '오시': 3,
#  '관계대명사': 2,
#  '전치사': 1,
#  '자주': 6,
#  '나오니': 1,
#  '기억': 2,
#  '저장': 2,
#  '롯데': 10,
#  '하이마트': 4,
#  '울산': 9,
#  '행사': 15,
#  '본인': 11,
#  '적용': 24,
#  '주목': 4,
#  '제휴': 1,
#  '카드': 10,
#  '결제': 3,
#  '시': 93,
#  '캐시': 1,
#  '이자': 2,
#  '가전': 1,
#  '환급': 1,
#  '휴대폰': 33,
#  '갤럭시': 16,
#  '버즈': 4,
#  '프로': 9,
#  '중고': 2,
#  '아이패드': 4,
#  '애플': 3,
#  '워치': 3,
#  '선물': 46,
#  '인기': 4,
#  '품목': 4,
#  '특별': 19,
#  '사은': 16,
#  '품': 9,
#  '수험': 6,
#  '노트북': 9,
#  '북': 4,
#  '메가스토어': 1,
#  '아이폰': 32,
#  '아이패드미니': 1,
#  '모바일': 3,
#  '퀴즈': 3,
#  '하자': 2,
#  '만큼': 24,
#  '맘껏': 10,
#  '예': 12,
#  '얘드': 7,
#  '논술': 8,
#  '청소년': 6,
#  '요금': 6,
#  '전용': 5,
#  '한정': 8,
#  '영화': 4,
#  '관람': 10,
#  '널': 9,
#  '팝콘': 2,
#  '교환': 2,
#  '선착순': 19,
#  '예매': 3,
#  '꼬리': 2,
#  '지급': 9,
#  '마감': 11,
#  '온라인': 3,
#  '현장': 12,
#  '학생증': 9,
#  '제시': 11,
#  '메가박스': 4,
#  '남': 4,
#  '춘천': 2,
#  '경기도': 4,
#  '김포시': 1,
#  '고촌읍': 1,
#  '수기': 1,
#  '캐슬': 1,
#  '힐': 2,
#  '브릭스': 1,
#  '리딩': 3,
#  '리더': 1,
#  '어학': 1,
#  '넌': 3,
#  '스짐': 4,
#  '망포': 4,
#  '방죽': 3,
#  '원점': 5,
#  '오직': 10,
#  '해당': 17,
#  '이벤': 4,
#  '동안': 11,
#  '타이': 1,
#  '트': 4,
#  '라인': 14,
#  '시선집중': 2,
#  '완벽': 2,
#  '잡채': 1,
#  '새내기': 1,
#  '수원': 3,
#  '망포동': 1,
#  '만족도': 4,
#  '호텔': 2,
#  '최고급': 6,
#  '팀': 8,
#  '강': 8,
#  '환경': 9,
#  '분위기': 4,
#  '도우미': 1,
#  '상시': 5,
#  '대기': 10,
#  '방역': 6,
#  '칙': 1,
#  '소독': 6,
#  '오전': 18,
#  '점심': 1,
#  '담당': 2,
#  '구역': 2,
#  '청소': 3,
#  '입장': 7,
#  '발열': 1,
#  '체크': 2,
#  '손소독': 1,
#  '지상': 2,
#  '창문': 1,
#  '개방': 1,
#  '환기': 2,
#  '막': 3,
#  '대형': 6,
#  '공기청정기': 1,
#  '상': 4,
#  '가동': 1,
#  '요즘': 10,
#  '결합': 10,
#  '혼자': 4,
#  '가구': 2,
#  '부부': 2,
#  '결': 1,
#  '인터넷': 8,
#  '텔레콤': 1,
#  '율': 4,
#  '하직': 1,
#  '영점': 1,
#  '가계': 2,
#  '통신비': 2,
#  '절감': 2,
#  '현금': 7,
#  '캡스': 1,
#  '매직': 1,
#  '상조': 1,
#  '맞춤': 18,
#  '기능': 4,
#  '동구': 4,
#  '안심로': 1,
#  '흥': 1,
#  '삭제': 4,
#  '꿈': 12,
#  '월': 24,
#  '개시': 3,
#  '사람': 12,
#  '온': 3,
#  '정석': 1,
#  '에스': 5,
#  '워': 3,
#  '광주': 5,
#  '봉선점': 3,
#  '표준': 1,
#  '여개': 1,
#  '직영': 3,
#  '리포머': 2,
#  '바렐': 2,
#  '체어': 2,
#  '어플': 8,
#  '시스템': 5,
#  '실력': 6,
#  '입문': 2,
#  '패키지': 5,
#  '커플': 3,
#  '듀엣': 9,
#  '근육': 9,
#  '과': 6,
#  '체계': 10,
#  '체험': 14,
#  '광역시': 3,
#  '남구': 1,
#  '봉선': 1,
#  '깔꼼': 1,
#  '젤': 1,
#  '네이버': 15,
#  '리뷰': 9,
#  '작성': 12,
#  '중복': 11,
#  '아트': 2,
#  '고양시': 2,
#  '네일': 3,
#  '집중': 7,
#  '잠시': 4,
#  '해도': 7,
#  '건': 7,
#  '바로': 17,
#  '사자': 2,
#  '어른': 3,
#  '타도': 1,
#  '떡': 4,
#  '친': 5,
#  '구랍': 1,
#  '덕분': 4,
#  '웃음': 1,
#  '도서관': 5,
#  '용': 3,
#  '최저': 7,
#  '바람': 4,
#  '재수': 3,
#  '결심': 1,
#  '내년': 2,
#  '마음가짐': 2,
#  '지구과학': 3,
#  '한국말': 1,
#  '이유': 9,
#  '밤': 4,
#  '다이어리': 4,
#  '종료': 9,
#  '연초': 1,
#  '모트': 4,
#  '마침': 2,
#  '잠깐': 4,
#  '쉬': 7,
#  '등촌': 1,
#  '가양': 1,
#  '염창역': 1,
#  '디렉터': 1,
#  '에이스': 2,
#  '침대': 3,
#  '엊그제': 2,
#  '거': 13,
#  '향': 4,
#  '달리': 1,
#  '관심': 12,
#  '사랑': 9,
#  '배': 9,
#  '자녀': 2,
#  '서랍': 1,
#  '포스팅': 1,
#  '눈': 16,
#  '좀': 5,
#  '매니저': 1,
#  '설명': 7,
#  '슈퍼': 1,
#  '싱글': 1,
#  '프로모션': 15,
#  '매트리스': 1,
#  '커버': 3,
#  '금액': 6,
#  '진시': 3,
#  '조기': 6,
#  '잠': 1,
#  '무료': 40,
#  '배송': 2,
#  '평일': 16,
#  '오후': 24,
#  '금토일': 1,
#  '용문역': 1,
#  '출구': 8,
#  '짐': 35,
#  '무려': 8,
#  '반값': 3,
#  '나볼': 1,
#  '맞이': 3,
#  '몸': 24,
#  '맞팔': 7,
#  '계점': 2,
#  '헛되다': 1,
#  '명예': 1,
#  '일련': 1,
#  ...}

# %%
sorted_voca = sorted(voca.items(), key = lambda item: item[1], reverse = True)
print(sorted_voca)
# Out:
# [('수험생', 409), ('이벤트', 362), ('수능', 349), ('할인', 250), ('여러분', 175), ('문의', 163), ('점', 161), ('고생', 142), ('수', 130), ('준비', 127), ('필라테스', 119), ('위해', 108), ('수험표', 105), ('혜택', 97), ('시', 93), ('상담', 92), ('동탄', 91), ('분', 86), ('위', 86), ('모두', 76), ('우리', 76), ('공부', 75), ('진행', 75), ('수고', 72), ('모든', 71), ('및', 71), ('시술', 71), ('응원', 69), ('당첨', 69), ('더', 69), ('개월', 69), ('기간', 68), ('추가', 65), ('시험', 63), ('고', 62), ('운동', 61), ('참여', 59), ('프로필', 59), ('방문', 58), ('가능', 57), ('시간', 57), ('예약', 55), ('전화', 55), ('시작', 55), ('것', 54), ('명', 53), ('이제', 53), ('학년', 53), ('바디', 53), ('층', 53), ('헬스', 51), ('그동안', 51), ('끝', 50), ('최대', 50), ('구매', 49), ('오늘', 48), ('회원', 48), ('카카오', 48), ('레슨', 48), ('지금', 48), ('댓글', 47), ('츠', 47), ('후', 47), ('결과', 46), ('가족', 46), ('선물', 46), ('친구', 45), ('머리', 44), ('저희', 44), ('앞', 43), ('등록', 43), ('개인', 42), ('이', 42), ('대학', 42), ('헤어', 42), ('꼭', 41), ('발표', 40), ('쿠팡', 40), ('무료', 40), ('중', 39), ('링크', 39), ('팔로우', 38), ('전', 38), ('통해', 36), ('사용', 36), ('인스타그램', 35), ('능력', 35), ('동반', 35), ('인', 35), ('짐', 35), ('학생', 34), ('확인', 34), ('수업', 34), ('톡', 34), ('날', 34), ('방법', 33), ('고객', 33), ('때', 33), ('나', 33), ('휴대폰', 33), ('다이어트', 33), ('내', 32), ('지문', 32), ('게시', 32), ('필수', 32), ('기구', 32), ('이상', 32), ('수학', 32), ('서비스', 32), ('아이폰', 32), ('재고', 32), ('채널', 31), ('국어', 31), ('그룹', 31), ('등', 31), ('카톡', 31), ('도', 30), ('염색', 30), ('생각', 30), ('쿠폰', 30), ('나루', 30), ('확률', 29), ('경품', 29), ('로', 29), ('미용실', 29), ('다비치', 29), ('태그', 28), ('추천', 28), ('번', 28), ('이번', 28), ('노력', 28), ('가격', 28), ('글', 27), ('탈색', 27), ('제외', 27), ('전문', 27), ('보유', 27), ('증정', 27), ('운영', 27), ('일', 27), ('안경', 27), ('제공', 26), ('제', 26), ('정답', 26), ('관리', 26), ('펌', 25), ('남자', 25), ('마음', 25), ('아이', 24), ('계정', 24), ('최고', 24), ('적용', 24), ('만큼', 24), ('월', 24), ('오후', 24), ('몸', 24), ('컬러', 24), ('걱정', 24), ('잇츠짐', 24), ('당장', 23), ('저', 23), ('지원', 23), ('물', 22), ('문제', 22), ('헬스장', 22), ('추첨', 22), ('가지', 22), ('컷', 22), ('메세지', 22), ('대상', 22), ('서울', 21), ('그', 21), ('이용', 21), ('영역', 21), ('첫', 21), ('어디', 21), ('신라', 21), ('명과', 21), ('변경', 20), ('오픈', 20), ('말', 20), ('속눈썹', 20), ('고민', 20), ('클래스', 20), ('뷰티', 20), ('풀', 19), ('리그', 19), ('램', 19), ('부분', 19), ('맛집', 19), ('사진', 19), ('교정', 19), ('스타', 19), ('그램', 19), ('검색', 19), ('매장', 19), ('산', 19), ('여자', 19), ('빛', 19), ('특별', 19), ('선착순', 19), ('양산', 19), ('정말', 18), ('분석', 18), ('인스타', 18), ('대전', 18), ('식사', 18), ('경우', 18), ('연락', 18), ('진행중', 18), ('오전', 18), ('맞춤', 18), ('부모님', 18), ('센터', 18), ('크리드', 18), ('다량', 18), ('영어', 17), ('목', 17), ('카페', 17), ('입시', 17), ('해', 17), ('알', 17), ('기말고사', 17), ('학교', 17), ('지난', 17), ('주차', 17), ('시설', 17), ('가장', 17), ('의', 17), ('디엠', 17), ('솔빛', 17), ('해당', 17), ('바로', 17), ('당일', 17), ('멀티', 17), ('렌즈', 17), ('화', 16), ('개별', 16), ('개', 16), ('한번', 16), ('법', 16), ('안내', 16), ('요', 16), ('보고', 16), ('갤럭시', 16), ('사은', 16), ('눈', 16), ('평일', 16), ('부담', 16), ('생', 16), ('벨킨', 16), ('학원', 16), ('스트레스', 16), ('내용', 16), ('포항', 16), ('디자인', 15), ('길', 15), ('무', 15), ('단', 15), ('독서', 15), ('탄솔', 15), ('행사', 15), ('네이버', 15), ('프로모션', 15), ('강사', 15), ('직접', 15), ('인생', 15), ('격려', 15), ('찹쌀떡', 15), ('비', 14), ('관', 14), ('과목', 14), ('면접', 14), ('성적', 14), ('학습', 14), ('편', 14), ('대한', 14), ('대해', 14), ('를', 14), ('환영', 14), ('라인', 14), ('체험', 14), ('부산', 14), ('체형', 14), ('허브', 14), ('기념', 14), ('건강', 14), ('차', 14), ('지수', 14), ('신청', 14), ('삼성', 14), ('다른', 13), ('합격', 13), ('총', 13), ('클릭', 13), ('거', 13), ('올해', 13), ('금', 13), ('한국', 13), ('간식', 13), ('장산', 13), ('특', 13), ('평', 12), ('주시', 12), ('난이도', 12), ('하나', 12), ('일정', 12), ('주', 12), ('하루', 12), ('트레이너', 12), ('천국', 12), ('사전', 12), ('취소', 12), ('교육', 12), ('가입', 12), ('대구', 12), ('다운', 12), ('예', 12), ('현장', 12), ('꿈', 12), ('사람', 12), ('작성', 12), ('관심', 12), ('토요일', 12), ('기회', 12), ('알바', 12), ('촬영', 12), ('만', 12), ('번호', 12), ('생활', 12), ('플러스', 12), ('응모', 12), ('캐논', 12), ('사항', 12), ('기업', ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
font_path ='C:\Windows\Fonts\malgun.ttf'
# fontprop = fm.FontProperties(fname=font_path, size=18)
im = Image.open('../../twitter_mask2.png') # 이미지 파일 읽어오기
mask=Image.new("RGB",im.size, (255,255,255))
mask.paste(im)
mask=np.array(mask)
wc=WordCloud(background_color='white',colormap='autumn', font_path = font_path, mask = mask)
wc=wc.generate_from_frequencies(voca)
plt.imshow(wc)

# %%
plt.show()

# %%
wc.to_file('test.png')

# %%
plt.imshow(wc)

# %%
plt.imshow(im)

# %%
import multidict as multidict

import numpy as np

import os
import re
from PIL import Image
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt


def getFrequencyDictForText(sentence):
    fullTermsDict = multidict.MultiDict()
    tmpDict = {}

    # making dict for counting frequencies
    for text in sentence.split(" "):
        if re.match("a|the|an|the|to|in|for|of|or|by|with|is|on|that|be", text):
            continue
        val = tmpDict.get(text, 0)
        tmpDict[text.lower()] = val + 1
    for key in tmpDict:
        fullTermsDict.add(key, tmpDict[key])
    return fullTermsDict


def makeImage(text):
    alice_mask = np.array(Image.open("../../twitter_mask2.png"))

    wc = WordCloud(background_color="white", max_words=1000, mask=alice_mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()


# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

text = open(path.join(d, '../../recent_list.txt'), encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [76], line 46
#      44 text = open(path.join(d, '../../recent_list.txt'), encoding='utf-8')
#      45 text = text.read()
# ---> 46 makeImage(getFrequencyDictForText(text))
#
# Cell In [76], line 33, in makeImage(text)
#      31 wc = WordCloud(background_color="white", max_words=1000, mask=alice_mask)
#      32 # generate word cloud
# ---> 33 wc.generate_from_frequencies(text)
#      35 # show
#      36 plt.imshow(wc, interpolation="bilinear")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:532, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     530 x, y = np.array(result) + self.margin // 2
#     531 # actually draw the text
# --> 532 draw.text((y, x), word, fill="white", font=transposed_font)
#     533 positions.append((x, y))
#     534 orientations.append(orientation)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageDraw.py:423, in ImageDraw.text(self, xy, text, fill, font, anchor, spacing, align, direction, features, language, stroke_width, stroke_fill, embedded_color, *args, **kwargs)
#     404 def text(
#     405     self,
#     406     xy,
#    (...)
#     420     **kwargs,
#     421 ):
#     422     if self._multiline_check(text):
# --> 423         return self.multiline_text(
#     424             xy,
#     425             text,
#     426             fill,
#     427             font,
#     428             anchor,
#     429             spacing,
#     430             align,
#     431             direction,
#     432             features,
#     433             language,
#     434             stroke_width,
#     435             stroke_fill,
#     436             embedded_color,
#     437         )
#     439     if embedded_color and self.mode not in ("RGB", "RGBA"):
#     440         raise ValueError("Embedded color supported only in RGB and RGBA modes")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageDraw.py:545, in ImageDraw.multiline_text(self, xy, text, fill, font, anchor, spacing, align, direction, features, language, stroke_width, stroke_fill, embedded_color)
#     543 line_spacing = self._multiline_spacing(font, spacing, stroke_width)
#     544 for line in lines:
# --> 545     line_width = self.textlength(
#     546         line, font, direction=direction, features=features, language=language
#     547     )
#     548     widths.append(line_width)
#     549     max_width = max(max_width, line_width)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageDraw.py:677, in ImageDraw.textlength(self, text, font, direction, features, language, embedded_color)
#     675 mode = "RGBA" if embedded_color else self.fontmode
#     676 try:
# --> 677     return font.getlength(text, mode, direction, features, language)
#     678 except AttributeError:
#     679     deprecate("textlength support for fonts without getlength", 10)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageFont.py:892, in TransposedFont.getlength(self, text, *args, **kwargs)
#     890 def getlength(self, text, *args, **kwargs):
#     891     if self.orientation in (Image.Transpose.ROTATE_90, Image.Transpose.ROTATE_270):
# --> 892         raise ValueError(
#     893             "text length is undefined for text rotated by 90 or 270 degrees"
#     894         )
#     895     return self.font.getlength(text, *args, **kwargs)
#
# ValueError: text length is undefined for text rotated by 90 or 270 degrees

# %%
# !pip install multidict
# Out:
# Collecting multidict
#   Downloading multidict-6.0.2-cp310-cp310-win_amd64.whl (27 kB)
# Installing collected packages: multidict
# Successfully installed multidict-6.0.2
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\kido7\appdata\local\programs\python\python310\lib\site-packages)

# %%
im = Image.open("../../twitter_mask.png")
mask=Image.new("RGB",im.size, (255,255,255))
# mask.paste(im,im)
mask=np.array(mask)
wc = WordCloud(mask=mask)
# generate word cloud
wc.generate_from_frequencies(voca)

# show
plt.imshow(wc)
# plt.axis("off")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:458, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     457 try:
# --> 458     font_size = int(2 * sizes[0] * sizes[1]
#     459                     / (sizes[0] + sizes[1]))
#     460 # quick fix for if self.layout_ contains less than 2 values
#     461 # on very small images it can be empty
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:464, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     463 try:
# --> 464     font_size = sizes[0]
#     465 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [92], line 7
#       5 wc = WordCloud(mask=mask)
#       6 # generate word cloud
# ----> 7 wc.generate_from_frequencies(voca)
#       9 # show
#      10 plt.imshow(wc)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud\wordcloud.py:466, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     464                 font_size = sizes[0]
#     465             except IndexError:
# --> 466                 raise ValueError(
#     467                     "Couldn't find space to draw. Either the Canvas size"
#     468                     " is too small or too much of the image is masked "
#     469                     "out.")
#     470 else:
#     471     font_size = max_font_size
#
# ValueError: Couldn't find space to draw. Either the Canvas size is too small or too much of the image is masked out.

# %%
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [82], line 1
# ----> 1 plt.imshow(im)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2623, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2617 @_copy_docstring_and_deprecators(Axes.imshow)
#    2618 def imshow(
#    2619         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2620         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2621         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2622         resample=None, url=None, data=None, **kwargs):
# -> 2623     __ret = gca().imshow(
#    2624         X, cmap=cmap, norm=norm, aspect=aspect,
#    2625         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2626         vmax=vmax, origin=origin, extent=extent,
#    2627         interpolation_stage=interpolation_stage,
#    2628         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2629         url=url, **({"data": data} if data is not None else {}),
#    2630         **kwargs)
#    2631     sci(__ret)
#    2632     return __ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:5604, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5596 self.set_aspect(aspect)
#    5597 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5598                       interpolation=interpolation, origin=origin,
#    5599                       extent=extent, filternorm=filternorm,
#    5600                       filterrad=filterrad, resample=resample,
#    5601                       interpolation_stage=interpolation_stage,
#    5602                       **kwargs)
# -> 5604 im.set_data(X)
#    5605 im.set_alpha(alpha)
#    5606 if im.get_clip_path() is None:
#    5607     # image does not already have clipping set, clip to axes patch
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\image.py:710, in _ImageBase.set_data(self, A)
#     706     self._A = self._A[:, :, 0]
#     708 if not (self._A.ndim == 2
#     709         or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710     raise TypeError("Invalid shape {} for image data"
#     711                     .format(self._A.shape))
#     713 if self._A.ndim == 3:
#     714     # If the input data has values outside the valid range (after
#     715     # normalisation), we issue a warning and then clip X to the bounds
#     716     # - otherwise casting wraps extreme values, hiding outliers and
#     717     # making reliable interpretation impossible.
#     718     high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (806, 980, 2) for image data
