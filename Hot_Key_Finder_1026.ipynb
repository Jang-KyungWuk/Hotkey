# %%
from requests import get, post, Session
from urllib import parse

# %%
def get_guest_token(): #guest token값을 return
    session = Session()
    headers = {
     'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA'
    }
    resp = session.post('https://api.twitter.com/1.1/guest/activate.json', headers = headers)
    resp.json()
    return resp.json()['guest_token']

# %%
def set_params(keyword): #header와 parameter값을 설정해준다.
    params = {'include_profile_interstitial_type': '1',
 'include_blocking': '1',
 'include_blocked_by': '1',
 'include_followed_by': '1',
 'include_want_retweets': '1',
 'include_mute_edge': '1',
 'include_can_dm': '1',
 'include_can_media_tag': '1',
 'include_ext_has_nft_avatar': '1',
 'skip_status': '1',
 'cards_platform': 'Web-12',
 'include_cards': '1',
 'include_ext_alt_text': 'true',
 'include_ext_limited_action_results': 'false',
 'include_quote_count': 'true',
 'include_reply_count': '1',
 'tweet_mode': 'extended',
 'include_ext_collab_control': 'true',
 'include_entities': 'true',
 'include_user_entities': 'true',
 'include_ext_media_color': 'true',
 'include_ext_media_availability': 'true',
 'include_ext_sensitive_media_warning': 'true',
 'include_ext_trusted_friends_metadata': 'true',
 'send_error_codes': 'true',
 'simple_quoted_tweet': 'true',
 'q': '',
 'tweet_search_mode': 'live',
 'count': '20',
 'query_source': 'recent_search_click',
 'pc': '1',
 'spelling_corrections': '1',
 'include_ext_edit_control': 'true',
 'ext': 'mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe'}
    
    headers = {'authority': 'twitter.com',
 'method': 'GET',
 'path': '/i/api/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=%23%EB%83%89%EB%8F%99%EB%A7%8C%EB%91%90&tweet_search_mode=live&count=20&query_source=recent_search_click&pc=1&spelling_corrections=1&include_ext_edit_control=true&ext=mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe',
 'scheme': 'https',
 'accept': '*/*',
 'accept-encoding': '',
 'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
 'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
 'cookie': 'guest_id_marketing=v1%3A166667526885979112; guest_id_ads=v1%3A166667526885979112; _ga=GA1.2.90083710.1666675272; _gid=GA1.2.208720928.1666675272; kdt=haoAurXsKba1QzgQArmyjksDpPIxI2NgYdsKXgdi; dnt=1; _sl=1; personalization_id="v1_s+fyK3WK3jNZxdSZKpb+4g=="; guest_id=v1%3A166676189695496518; ct0=c957e33ed33737a2fbe46ccce2767ad1; gt=1585140401979412480; g_state={"i_l":1,"i_p":1666769101996}',
 'referer': 'https://twitter.com/search?q=%23%EB%83%89%EB%8F%99%EB%A7%8C%EB%91%90&src=recent_search_click&f=live',
 'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
 'sec-ch-ua-mobile': '?0',
 'sec-ch-ua-platform': '"Windows"',
 'sec-fetch-dest': 'empty',
 'sec-fetch-mode': 'cors',
 'sec-fetch-site': 'same-origin',
 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
 'x-csrf-token': 'c957e33ed33737a2fbe46ccce2767ad1',
 'x-guest-token': '',
 'x-twitter-active-user': 'yes',
 'x-twitter-client-language': 'ko'}
    
    #parmas의 query를 keyword로 교체
    params['q'] = parse.quote('#'+keyword)
    #headers의 accept-encoding을 json으로 교체
    headers['accept-encoding'] = 'json'
    
    #headers의 x-guest-token 채우기
    #guest-token받아오기
    headers['x-guest-token'] = get_guest_token()
    
    #headers, parameters 설정 끝
    return (params, headers)

# %%
def hot_key_finder(keyword, n): #keyword는 검색할 변수, n은 최대 몇 페이지까지 검색할지
    #parameter 초기값 받아오기
    params, headers = set_params(keyword)
    
    #session 인스턴스 생성
    session = Session()
    request_url = 'https://twitter.com/i/api/2/search/adaptive.json'
    
    #get 요청을 보낼 url 완성하기
    keys = list(params.keys())
    values = list(params.values())
    get_request_url = request_url+'?'
    for cursor in range(len(keys)):
        get_request_url+='%s=%s&'%(keys[cursor],values[cursor]) 
    get_request_url = get_request_url[:-1]
    
    #headers의 'path' 변수 바꿔주기
    headers['path'] = get_request_url[19:]
    
    #get 요청 보내기 (1페이지)
    resp = session.get(get_request_url,headers=headers)
    
    #1페이지 검색
    print('---------------------------------------1페이지-----------------------------------------\n\n')
    for i in resp.json()['globalObjects']['tweets'].keys():
        print(resp.json()['globalObjects']['tweets'][i]['full_text'])
        
    #다음 페이지 가르키는 커서 변수에 값 넣어주기
    next_pg = resp.json()['timeline']['instructions'][0]['addEntries']['entries'][-1]['content']['operation']['cursor']['value']
    
    #2페이지부터 검색
    for i in range(n-1):
        params['cursor'] = next_pg
        get_request_url = request_url+'?'
        keys = list(params.keys())
        values = list(params.values())
        for cursor in range(len(keys)):
            get_request_url+='%s=%s&'%(keys[cursor],values[cursor]) 
        get_request_url = get_request_url[:-1]
        resp = session.get(get_request_url,headers=headers)
        next_pg = resp.json()['timeline']['instructions'][-1]['replaceEntry']['entry']['content']['operation']['cursor']['value']
        print('\n\n---------------------------------------{}페이지-----------------------------------------\n\n'.format(i+2))
        for i in resp.json()['globalObjects']['tweets'].keys():
            print(resp.json()['globalObjects']['tweets'][i]['full_text'])

# %%
hot_key_finder('한지민', 5)
# Out:
# ---------------------------------------1페이지-----------------------------------------
#
#
# [JIMINstagram📸]-Story
# ⠀
# 지민배우덕분에 느껴보는 가을풍경🍁
# ⠀
# #한지민 https://t.co/B1IlfB19Wb
# 🗓11월 최애돌셀럽 달력🗓
#
# 🎂셀럽의 생일을 축하합니다!
# #김민재 #케이데이 #이찬원 #김소연 #가비 #한석규 #소지섭 #한지민 #이동욱 #박지후 #김혜윤 #문채원 #박형식 #이용진 #김수찬 #한소희 #정진영 #드기 #도니 #송혜교 #이상이 등
#
# → 100일 단위 기념일: https://t.co/LaVGeF56mu https://t.co/BeEFP5Wtce
# 221025 한지민 인스타그램 스토리
#
# #한지민 https://t.co/ZnA46xkrJa
# 221007 221008 부산국제영화제 부국제 오픈토크 데이터 판매합니다
#
# 👉 R6 100-500
# 👉 욘더 한지민 신하균
# 브로커 아이유 이지은 이주영
# 20세기 소녀 김유정 변우석 박정우 노윤서
# 👉https://t.co/cLQdJMRsZH
#
# #한지민 #신하균 #아이유 #이지은 #이주영 #김유정 #변우석 #박정우 #노윤서 #데이터 https://t.co/eoVhMqtfiq
# 🌐욘더 스틸컷
#
# 이후와 이별하는 재현의 여정에 함께할 수 있어서 행복했어요! 부디 우리의 기억 속에서 내내 어여쁘소서🤎
#
# https://t.co/ONnzzMyIi7
#
# #한지민 #hanjimin #신하균 #욘더 https://t.co/5NLHOJ0jsX
# ෆ̈ ෆ⸒⸒*⁀➷ ❥･•𓈒𓏸 𓂂𓈒ᕱ ᕱ𓂂 𓈒𓏸
# 𝒘𝒊𝒕𝒉 𝒂𝒍𝒍 𝒐𝒖𝒓 𝒉𝒆𝒂𝒓𝒕, 𝒕𝒐 𝑯𝑱𝑴
# 2. https://t.co/ojBq7ix0Sc
# 3. https://t.co/cIRuDZtSsK https://t.co/FDb4tEEs9u
# 깊은 보조개에 숨 참고 Dive💘
#
# 🪂&lt;사랑의 불시착&gt; #현빈
# 👮🏻&lt;괴물&gt; #신하균
# 🗡&lt;도깨비&gt; #공유
# 💗&lt;내일 그대와&gt; #신민아
# 🌊&lt;우리들의 블루스&gt; #한지민
# 🦊&lt;간 떨어지는 동거&gt; #강한나
#
# #지금바로TVING
#
# #TVING #티빙 #사랑의불시착 #괴물 #도깨비 #내일그대와 #우리들의블루스 #간떨어지는동거 #보조개 https://t.co/CBzWvO1VJf
# ⠀
#
# 한지민 × 올리비아하슬러
#
# #한지민 #Hanjimin https://t.co/QgkYeuu63c
#
#
# ---------------------------------------3페이지-----------------------------------------
#
#
# #JaehyunYihu: always like water 🌊
#
# #Yonder #욘더 #ShinHakyun #신하균 #HanJimin #한지민 #재현이후
#  https://t.co/MJEimQLi7b
# 幸せな瞬間を見ているはずなのに
# 悲しくて切なくて、、、
#
# あるはずのない世界が存在していて、
# 亡くなった大事な人に会えるとしたら
# どうするだろう？
#
# 大切な記憶は忘れないまま
# 今、生きてる、現実の世界のこの瞬間を大事に生きたい
#
# #욘더 #신하균 #한지민
# #ヨンダー #シンハギュン #ハンジミン https://t.co/JCfxxTpTZV
# 지민배우 어깨 안마담당이셨던 욘더 다솜 스탭님의 행복 그 잡채였다던 욘더 촬영장🎬
# 지민배우 행복한 생일 맞이하게 해주셔서 감사합니다🎂
# 지민배우도 많이 그리울 욘더 촬영현장😭
# ⠀
# https://t.co/cCC3DKbRC2
# ⠀
# #한지민 https://t.co/C1XmKhemu8
# #떴수다
#
# 일콜을 멀리하다니.. 큰 결심한 지민배우🤣🤣🤣🤣
#
# #한지민 https://t.co/OXlh6KEDv5
# 🎈지민배우 생일 &amp; '힙하게' 서포트 모금중입니다🎉
#
# 🎈1만원 : 포토카드
#      3만원 : 1만원 특전+컴팩트 거울
#      5만원 : 3만원 특전+아코디언 카드
#      10만원 : 5만원 특전+그립톡
#      최고입금자 : 10만원 특전 + 지민배우 싸인)
# ⠀
# 🎈입금하시고👇
# https://t.co/3W1ls19TqB
#
# #한지민 https://t.co/CIC3bvEPFF
# 🍂점점 추워지는 가을
# 🥰시린 옆구리 따숩게 할 백허그
#
# ⛴#우리들의블루스 #김우빈 #한지민
# 🔭#내아이디는강남미인 #차은우 #임수향
# 💗#응답하라1988 #박보검 #혜리
# 🥺#런온 #임시완 #신세경
# 🌙#THEK2 #지창욱 #윤아
#
# @티즐리들이 픽한 백허그 장면은?
# #지금바로TVING #TVING #티빙 https://t.co/XtcKTazSgq
# ジミンさん益々好きになった🥹
# ジミンさんの感情演技もやはり引き込まれる🥲🫶🏻
# 幸せいっぱいのシーンと胸締め付けられるシーンの差が😭😭😭
# まだ見てない作品も沢山あるので見たいのとイミンギ氏との次期作楽しみに待ってます🥹💞
#
# #욘더 #한지민
# #ヨンダー #ハンジミン https://t.co/JKhdNB1KR3
# 올리비아 하슬러 2022F/W 화보🍁❄️
# ⠀
# #한지민 https://t.co/F8uArGhu3a
# 221006 부산국제영화제 티빙오리지널 욘더 GV 한지민
# #부산국제영화제 #BIFF #티빙 #욘더 #한지민 https://t.co/QbEDaymKhE
# #떴수다
# ⠀
# 혜자야😭😭😭😭😭😭😭
# ⠀
# #한지민 https://t.co/Yuxqh3FAUl
# 写真いっぱいありがとうございます🥹
#
# イフとジェヒョンの海のシーンが忘れられないㅠㅠㅠ
#
# ジミンさんコメントお返事されてたけど本当に色々考えさせられた…
#
# もしそんな世界があるとしたら…
# 得るもの失うもの、というか
# それは幸せなのかな？分からない…
#
# #욘더 #한지민
# #ヨンダー #ハンジミン https://t.co/8kuZ27fF6H
# 221022 한지민 인스타그램 스토리
#
# #한지민 https://t.co/WISd1n9aci
# 🎥떴수다 EP.6 욘더
#
# 떴수다 유튜브도 올라왔네요! 아직 못 보신 분들 고고💓
#
# https://t.co/pDZGOEKGQu
#
# #한지민 #hanjimin #신하균 #욘더
# #떴수다
# ⠀
# 생각하고싶지않은 순간이네요🥲
# ✔️풀버젼은 티빙에서 보실 수 있습니다🤗
# ⠀
# #한지민 https://t.co/ziTMi8CpxM
# [INSTAGRAM] : dsom.a
#
# 최고의 안마와 신나는 깜짝 생파 영상들💜
# 최고의 스탭들과 행복한 현장에서 즐겁게 촬영한 욘더 보러가세요😆
#
# https://t.co/Naqh5mzyzi
#
# #한지민 #hanjimin #욘더 https://t.co/TkGsbVN1hR
# [INSTAGRAM]
#
# 떴수다 스탭분이 올려주신 사진☺️
#
# #한지민 #hanjimin #신하균 https://t.co/3byVfKC14P
# ジミンさんがアップしてくれた写真😭😭😭😭😭
#
# #욘더 #신하균 #한지민
# #ヨンダー #シンハギュン #ハンジミン https://t.co/RLxZQnY6Wu
# 221022 한지민 인스타그램
#
# #한지민 https://t.co/rjAtFh1K6R
# 욘더가 뭐야?
#
# 내가 있는 곳
#
# 거기가 어디야?
#
# 당신이 없는 곳
#
# ここのジミンさんハギュンさんの演技ㅠㅠㅠㅠㅠ何回も巻き戻した、引き込まれたㅠㅠㅠ画面に吸い込まれて胸が痛すぎたㅠㅠㅠㅠ
#
# #욘더 #신하균 #한지민
# #ヨンダー #シンハギュン #ハンジミン https://t.co/Y8ICSoTG4A
# ⠀
#
# 분위기 좋은 욘더팀☺
# 영상 감사합니다🤍🤍
#
# TVING 오리지널 '욘더' 10월 14, 21일 대공개✔️
#
# #한지민 #Hanjimin https://t.co/5DlO3NXJvY
#
#
# ---------------------------------------4페이지-----------------------------------------
#
#
# 떴수다 스탭분 인스타그램📸
# 부럽습니다🥲🥲🥲
#
# https://t.co/LYIuL0sN9U
#
# #한지민 https://t.co/rWqamTEE2Y
# 떴수다 공개되었어요!
# 지금 바로 티빙에서 보실 수 있어요😆
# (너무 웃기고 너무 재밌음ㅋㅋㅋㅋㅋㅋ)
#
# #한지민 #hanjimin #신하균 #욘더
# #떴수다
# ⠀
# 지민배우는 너무 예뻐서 전생에서 봤어도 기억할수 있을것같습니다!🙋‍♀️
# ⠀
# #한지민 https://t.co/rIKEb5Lci6
# ⠀
#
# 욘더 사진첩💌
#
# TVING 오리지널 '욘더' 10월 14, 21일 대공개✔️
#
# #한지민 #Hanjimin https://t.co
#
# TVING 오리지널 '욘더' 10월 14, 21일 대공개✔️
#
# #한지민 #Hanjimin @roma.emo https://t.co/ISEZwp5KbP
# [JIMINstagram📸]-Story
# ⠀
# 신하균 배우님.. 과자 안좋아하고 견과류 드신다면서요..🤣🤣
# 두분 케미 넘 좋았어요👍👍
# ⠀
# #한지민 https://t.co/e1Nvt1XuKp
# 떴수다에서 기다릴게.. 거기로 와줘,,, from 욘더
# 떡상맛집을 찾은 6번째 손님 &lt;욘더&gt; 신하균 X 한지민
#
# 기억해🧠 내일 10/22(토) 낮 2시
# &lt;떴수다&gt; '욘더' 편 TVING에서 무료공개!
#
# #티빙오리지널 #떴수다 #욘더 #장도연 #신하균 #한지민 #티빙 #TVING https://t.co/ItLZUlUyKE
# 🔈생일 해시태그 투표
#
# 카페에서 생일 해시태그 투표 중입니다!
# 카페로 가셔서 많이많이 투표해주세요☺️
#
# https://t.co/UZfBxErJYx
#
# #한지민 #hanjimin #한지민단하나 #지민단
# ⠀
#
# 욘더 사진첩💌
#
# TVING 오리지널 '욘더' 10월 14, 21일 대공개✔️
#
# #한지민 #Hanjimin https://t.co/lFBzk1LoGO
# [JIMSTAGRAM STORY] : 221022
#
# 군것질 안좋아하는 사람과 너무 좋아하는 사람이 만나면?
#
# 둘 다 좋아하게 된다🤣🤣
#
# #한지민 #hanjimin #신하균 #욘더 https://t.co/Boq5oSdrjR
# ---------------------------------------5페이지-----------------------------------------
#
#
# ⠀
#
# [NO. 1377] BIFF X &lt;씨네21&gt; 📸
#
# "&lt;욘더&gt;거 주는 여운은 사랑하는 사람에 대한 그리움이나 이별로
# 인한 아픔, 슬픔보다는 인간의 죽음을 본질적으로 고민하는 쪽에
# 가까웠다." (한지민)
#
# TVING 오리지널 '욘더' 10월 14일 첫방송✔️
#
# #한지민 #Hanjimin https://t.co/136FEcZhdv
# #떴수다 &lt;욘더&gt; 편 지금 티빙에서!!!
#
# 🔗https://t.co/ajmsZXyiac
#
# 드디어 갈머도연 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ
#
# #장도연 #신하균 #한지민 https://t.co/uMBIGKJeAq
# ⠀
#
# 한지민 × 올리비아하슬러
#
# #한지민 #Hanjimin https://t.co/IZjBT7W1aU
# ⠀
#
# TVING 오리지널 '욘더' 10월 14, 21일 대공개✔️
#
# #한지민 #Hanjimin https://t.co/3IRyygHEAA
# 차이후 찐광기 그잡채였던 장면
# 연기 살살좀요;;
# #욘더 #한지민 https://t.co/st38mgc4Ru
# 이준익감독이 왜 이장면 머리에 박제돼버렸다고 하셨는지 걍 바로 이해함...부부가 함께 하늘을 쳐다보는 장면이 이렇게 소름끼치게 느껴질수 있는걸까요...하늘이 닫히고 해가 잠기고 한 사람은 눈을 감고 한 사람은 눈을 뜨고 있는 대비에 그냥 말로 형언할수 없는 감정이 듬 #욘더 #신하균 #한지민 https://t.co/pbC983ureV
# [BH알리미]
# 세상을 떠난 아내 ‘이후’가 보낸 메시지를 받은 ‘재현’이
# 죽은 자의 기억으로 만든 세계 &lt;욘더&gt;로 향합니다.
#
# 이후 “모든 걸 다 버렸는데도 잊히지 않는다면 그것만은 잃어버리고 싶지 않았기 때문이야.”
#
# 과연 이들에게 &lt;욘더&gt;는 불멸의 행복이자 영원한 천국이 될 수 있을까요?
#
# #한지민 https://t.co/WC3vg8Qn0d
# 한지민 - 욘더 인별 &amp; 씨네21 &amp; 티빙
# #한지민 #욘더 #인별 #씨네21 #티빙
# https://t.co/xtjhADK2Yv
# &lt;욘더&gt; 4~6화 공개까지 1시간 👀❤
# 리뷰 남기고 친필 싸인 포스터 받아가세욘
# 잠시 후 4시에 공개될 4~6화도 많관부(❁´◡`❁)
#
# *당첨자는 개별 DM으로 고지됩니다.
# *본 이벤트는 티빙 인스타그램, 트위터에서만 진행됩니다.
#
# #티빙오리지널 #욘더 #YONDER #신하균 #한지민 #이정은 #정진영 #이준익 https://t.co/pVBmri6vhV
# 욘더의 이후와 재현👫
# ⠀
# #한지민 https://t.co/2WYW0c6Smo
# [JIMINstagram📸]
# ⠀
# 욘더 사진첩 💌
# .
# #욘더 #YONDER #TVING
# ⠀
# #한지민 https://t.co/eP0wzJXjPu
# 티빙 오리지널 ‘욘더’ 의미 심장 OST 연달아 공개…신하균·한지민 가슴 시린 서사 표현할 손디아 ‘DIVER’+이승열 ‘잊게 될거야’ 발매
# #티빙 #오리지널 #욘더 #Ost #공개 #신하균 #한지민 #서사 #손디아 #이승열
#
# https://t.co/Ad7Oy1sbVP
# 올리비아 하슬러 2022 FW 화보🍁❄️
# ⠀
# #한지민 https://t.co/yFS4BkuxtG
# 떡상맛집을 찾은 6번째 손님 &lt;욘더&gt; 신하균 X 한지민
# 기억해🧠 내일 10/22(토) 낮 2시
# &lt;떴수다&gt; '욘더' 편 TVING에서 무료공개!
# ⠀
#  #한지민 https://t.co/mZbQQN8WiN
# "욘더가 뭐야?"
# "내가 있는 곳."
# "거기가 어디야?"
#
# 예고에 나왔던 이 장면 다음에 이어지는 이후의 대답이 진짜 미치도록 슬펐음......재현이 눈에서 흘러내리는 눈물도 그냥 심장 박박쪼개짐...서로 닿을 수 없는 감정과 존재의 막막함이 여기까지 느껴짐.... #욘더 #신하균 #한지민 https://t.co/ZDFYATqrDA
# 떴수다에서 기다릴게.. 거기로 와줘,,, from 욘더
# 떡상맛집을 찾은 6번째 손님 &lt;욘더&gt; 신하균 X 한지민
#
# 기억해🧠 내일 10/22(토) 낮 2시
# &lt;떴수다&gt; '욘더' 편 TVING에서 무료공개!
#
# #티빙오리지널 #떴수다 #욘더 #장도연 #신하균 #한지민 #티빙 #TVING https://t.co/ItLZUlUyKE
# このスマホケースどこのだろう？
# 検索能力カス過ぎて見つけられない😭
#
# #ハンジミン
# #한지민 https://t.co/4Hx7F1ZHaV
# “아름다운 기억이 소중한 것은 그 순간이 다시 돌아오지 않기 때문이다.”
# 하지만 욘더는 티빙에서 계속 돌려볼 것이다💕 #티빙오리지널 #욘더 #신하균 #한지민 #정진영 #이정은 #이준익 #욘더리뷰
# 김재현 이자식 소심하게 미역국 복수하는 거 진짜 개귀엽고 한대 때려주고싶음 으이그 #욘더 #신하균 #한지민 https://t.co/zhxSCazmRN
# ㅤㅤㅤ
# 한지민, 김혜수 간식차 인증…"맛있게 잘 먹었습니다"
# ㅤㅤㅤ
# #한지민 #김혜수 #간식 #차 #인증 ㅤhttps://t.co/rHvSYswLa9
